# %% [markdown]
# I use FoCS environment. Python 3.11.6 version.

# %%
# Import useful libraries
import os
import json
import re
import pandas as pd
import numpy as np
from collections import defaultdict

# %%
# Configuration file
with open('config.json', 'r') as f:
    config = json.load(f)

# %%
# Set the display options to show numbers without scientific notation
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %% [markdown]
# You have to work on the [ZTBus: A Large Dataset of Time-Resolved City Bus Driving Missions](https://www.research-collection.ethz.ch/handle/20.500.11850/626723) repository.
#
# It contains:
# *  [metaData.csv](https://www.research-collection.ethz.ch/bitstream/handle/20.500.11850/626723/metaData.csv?sequence=1&isAllowed=y), shortly *trips*
# *  several other files containing detailed data on some bus parameters, whose name is in the *trips* file. Those files can be downloaded as a [zip file](https://www.research-collection.ethz.ch/bitstream/handle/20.500.11850/626723/ZTBus_compressed.zip?sequence=3&isAllowed=y). Let us call those datasets the *details* datasets.

# %% [markdown]
# # Import

# %% [markdown]
# **ZT_bus Folder Structure**: The 'ZT_bus' folder is the main directory containing data related to driving missions.
# Inside this folder, you'll find information on 1409 driving missions.
#
# **Metadata Information**: Additionally, there is a 'metadata' folder that stores metadata related to these missions.
# The metadata includes information for all 1490 missions.

# %% [markdown]
# ## Metadata csv

# %%
metadata = pd.read_csv(config['path_metadata'])

# %%
metadata.head()
# Out:
#                                            name  busNumber  \
# 0  B183_2019-04-30_03-18-56_2019-04-30_08-44-20        183
# 1  B183_2019-04-30_13-22-07_2019-04-30_17-54-02        183
# 2  B183_2019-05-01_05-58-51_2019-05-01_22-32-30        183
# 3  B183_2019-05-03_02-50-21_2019-05-03_05-53-20        183
# 4  B183_2019-05-03_15-41-57_2019-05-03_23-06-24        183
#
#           startTime_iso  startTime_unix           endTime_iso  endTime_unix  \
# 0  2019-04-30T03:18:56Z      1556594336  2019-04-30T08:44:20Z    1556613860
# 1  2019-04-30T13:22:07Z      1556630527  2019-04-30T17:54:02Z    1556646842
# 2  2019-05-01T05:58:51Z      1556690331  2019-05-01T22:32:30Z    1556749950
# 3  2019-05-03T02:50:21Z      1556851821  2019-05-03T05:53:20Z    1556862800
# 4  2019-05-03T15:41:57Z      1556898117  2019-05-03T23:06:24Z    1556924784
#
#    drivenDistance busRoute  energyConsumption  itcs_numberOfPassengers_mean  \
# 0       77213.870        -      478585200.000                         5.539
# 1       59029.600       31      402258500.000                        33.115
# 2      240900.400       33     1445733000.000                        19.689
# 3       42565.480        -      281986700.000                         1.685
# 4      125277.200       72      620725800.000                        23.754
#
#    itcs_numberOfPassengers_min  itcs_numberOfPassengers_max  \
# 0                            0                           20
# 1                            4                           74
# 2                            0                           55
# 3                            0                            8
# 4                            1                           67
#
#    status_gridIsAvailable_mean  temperature_ambient_mean  \
# 0                        0.741                   282.378
# 1                        0.855                   287.544
# 2                        0.778                   288.749
# 3                        0.767                   282.413
# 4                        0.907                   284.733
#
#    temperature_ambient_min  temperature_ambient_max
# 0                  281.150                  293.150
# 1                  285.150                  293.150
# 2                  280.150                  294.150
# 3                  281.150                  292.150
# 4                  282.150                  287.150

# %%
metadata.shape
# Out:
# (1409, 16)

# %%
# Check metadata dtypes
metadata.dtypes
# Out:
# name                             object
# busNumber                         int64
# startTime_iso                    object
# startTime_unix                    int64
# endTime_iso                      object
# endTime_unix                      int64
# drivenDistance                  float64
# busRoute                         object
# energyConsumption               float64
# itcs_numberOfPassengers_mean    float64
# itcs_numberOfPassengers_min       int64
# itcs_numberOfPassengers_max       int64
# status_gridIsAvailable_mean     float64
# temperature_ambient_mean        float64
# temperature_ambient_min         float64
# temperature_ambient_max         float64
# dtype: object

# %% [markdown]
# `startTime_iso` has `object` format. It should be a `datetime` object. Later, when this variable will be used for analysis it will be better to change the format or to use `startTime_unix`. The same regards the `endTime_iso` variable. The other format are correct for the nature of the variable they represent.

# %% [markdown]
# ### Nan values check

# %%
metadata.isna().sum()
# Out:
# name                            0
# busNumber                       0
# startTime_iso                   0
# startTime_unix                  0
# endTime_iso                     0
# endTime_unix                    0
# drivenDistance                  0
# busRoute                        0
# energyConsumption               0
# itcs_numberOfPassengers_mean    0
# itcs_numberOfPassengers_min     0
# itcs_numberOfPassengers_max     0
# status_gridIsAvailable_mean     0
# temperature_ambient_mean        0
# temperature_ambient_min         0
# temperature_ambient_max         0
# dtype: int64

# %%
print(f'Metadata dataframes has: {metadata.isna().sum().sum()} null values.')
# Out:
# Metadata dataframes has: 0 null values.

# %% [markdown]
# Dataset does not contain nan values.

# %% [markdown]
# ## Import ZT_bus data

# %%
file_names = [file_name for file_name in os.listdir(config['path_ZTbus_folder']) if 
              os.path.isfile(os.path.join(config['path_ZTbus_folder'], file_name))]

# %%
# Print only the first 10 results
file_names[:10]
# Out:
# ['B183_2020-11-13_14-52-45_2020-11-13_19-13-45.csv',
#  'B183_2020-10-06_04-23-44_2020-10-06_07-33-54.csv',
#  'B183_2019-10-03_03-04-42_2019-10-03_18-38-45.csv',
#  'B183_2022-05-02_03-02-19_2022-05-02_17-07-49.csv',
#  'B183_2021-04-23_03-47-54_2021-04-23_07-48-48.csv',
#  'B208_2022-08-15_03-31-51_2022-08-15_12-34-10.csv',
#  'B183_2020-07-24_04-01-31_2020-07-24_18-04-39.csv',
#  'B183_2022-10-28_13-36-23_2022-10-28_16-37-08.csv',
#  'B208_2021-04-21_04-10-07_2021-04-21_18-19-32.csv',
#  'B183_2022-07-28_14-27-33_2022-07-28_19-17-23.csv']

# %%
len(file_names) == metadata.shape[0]
# Out:
# True

# %% [markdown]
# As expected, ZT_bus folder contains data related to 1409 driving missions and metadata contains information related to that missions (always 1490).

# %%
dataframes = {}
for el in file_names:
    dataframes[el[:-4]] = pd.read_csv(f'{config["path_ZTbus_folder"]}/{el}')

# %%
type(dataframes)
# Out:
# dict

# %% [markdown]
# `dataframes` is a dictionary of dataframes, in total 1490. Each of them correspond to a driving mission.

# %%
# Print the first 10 keys
list(dataframes.keys())[:10]
# Out:
# ['B183_2020-11-13_14-52-45_2020-11-13_19-13-45',
#  'B183_2020-10-06_04-23-44_2020-10-06_07-33-54',
#  'B183_2019-10-03_03-04-42_2019-10-03_18-38-45',
#  'B183_2022-05-02_03-02-19_2022-05-02_17-07-49',
#  'B183_2021-04-23_03-47-54_2021-04-23_07-48-48',
#  'B208_2022-08-15_03-31-51_2022-08-15_12-34-10',
#  'B183_2020-07-24_04-01-31_2020-07-24_18-04-39',
#  'B183_2022-10-28_13-36-23_2022-10-28_16-37-08',
#  'B208_2021-04-21_04-10-07_2021-04-21_18-19-32',
#  'B183_2022-07-28_14-27-33_2022-07-28_19-17-23']

# %%
len(dataframes.keys())
# Out:
# 1409

# %% [markdown]
# Let's take two samples dataframes to analyse.

# %%
dataframes['B183_2019-04-30_03-18-56_2019-04-30_08-44-20'].head()
# Out:
#                time_iso   time_unix  electric_powerDemand  gnss_altitude  \
# 0  2019-04-30T03:18:56Z  1556594336               -13.846            NaN
# 1  2019-04-30T03:18:57Z  1556594337                -3.849            NaN
# 2  2019-04-30T03:18:58Z  1556594338                -0.672            NaN
# 3  2019-04-30T03:18:59Z  1556594339                -1.088            NaN
# 4  2019-04-30T03:19:00Z  1556594340                -0.812            NaN
#
#    gnss_course  gnss_latitude  gnss_longitude itcs_busRoute  \
# 0          NaN            NaN             NaN             -
# 1          NaN            NaN             NaN             -
# 2          NaN            NaN             NaN             -
# 3          NaN            NaN             NaN             -
# 4          NaN            NaN             NaN             -
#
#    itcs_numberOfPassengers itcs_stopName  ...  odometry_wheelSpeed_mr  \
# 0                      NaN             -  ...                   0.000
# 1                      NaN             -  ...                   0.000
# 2                      NaN             -  ...                   0.000
# 3                      NaN             -  ...                   0.000
# 4                      NaN             -  ...                   0.000
#
#    odometry_wheelSpeed_rl  odometry_wheelSpeed_rr  status_doorIsOpen  \
# 0                   0.000                   0.000                  1
# 1                   0.000                   0.000                  1
# 2                   0.000                   0.000                  1
# 3                   0.000                   0.000                  1
# 4                   0.000                   0.000                  1
#
#    status_gridIsAvailable  status_haltBrakeIsActive  status_parkBrakeIsActive  \
# 0                       1                         0                         0
# 1                       1                         0                         0
# 2                       1                         0                         0
# 3                       1                         0                         0
# 4                       1                         0                         0
#
#    temperature_ambient  traction_brakePressure  traction_tractionForce
# 0              293.150              251666.700                   0.000
# 1              292.369              254876.200                   0.000
# 2              292.931              251783.300                   0.000
# 3              293.150              255000.000                   0.000
# 4              293.150              253000.000                   0.000
#
# [5 rows x 26 columns]

# %%
dataframes['B183_2019-04-30_03-18-56_2019-04-30_08-44-20'].columns
# Out:
# Index(['time_iso', 'time_unix', 'electric_powerDemand', 'gnss_altitude',
#        'gnss_course', 'gnss_latitude', 'gnss_longitude', 'itcs_busRoute',
#        'itcs_numberOfPassengers', 'itcs_stopName',
#        'odometry_articulationAngle', 'odometry_steeringAngle',
#        'odometry_vehicleSpeed', 'odometry_wheelSpeed_fl',
#        'odometry_wheelSpeed_fr', 'odometry_wheelSpeed_ml',
#        'odometry_wheelSpeed_mr', 'odometry_wheelSpeed_rl',
#        'odometry_wheelSpeed_rr', 'status_doorIsOpen', 'status_gridIsAvailable',
#        'status_haltBrakeIsActive', 'status_parkBrakeIsActive',
#        'temperature_ambient', 'traction_brakePressure',
#        'traction_tractionForce'],
#       dtype='object')

# %%
dataframes['B183_2019-04-30_03-18-56_2019-04-30_08-44-20'].shape
# Out:
# (19525, 26)

# %%
dataframes['B183_2019-04-30_03-18-56_2019-04-30_08-44-20'].dtypes
# Out:
# time_iso                       object
# time_unix                       int64
# electric_powerDemand          float64
# gnss_altitude                 float64
# gnss_course                   float64
# gnss_latitude                 float64
# gnss_longitude                float64
# itcs_busRoute                  object
# itcs_numberOfPassengers       float64
# itcs_stopName                  object
# odometry_articulationAngle    float64
# odometry_steeringAngle        float64
# odometry_vehicleSpeed         float64
# odometry_wheelSpeed_fl        float64
# odometry_wheelSpeed_fr        float64
# odometry_wheelSpeed_ml        float64
# odometry_wheelSpeed_mr        float64
# odometry_wheelSpeed_rl        float64
# odometry_wheelSpeed_rr        float64
# status_doorIsOpen               int64
# status_gridIsAvailable          int64
# status_haltBrakeIsActive        int64
# status_parkBrakeIsActive        int64
# temperature_ambient           float64
# traction_brakePressure        float64
# traction_tractionForce        float64
# dtype: object

# %%
dataframes['B208_2022-03-25_23-51-19_2022-03-26_03-42-34'].head()
# Out:
#                time_iso   time_unix  electric_powerDemand  gnss_altitude  \
# 0  2022-03-25T23:51:19Z  1648252279              2795.944            NaN
# 1  2022-03-25T23:51:20Z  1648252280              2717.339            NaN
# 2  2022-03-25T23:51:21Z  1648252281              2904.655            NaN
# 3  2022-03-25T23:51:22Z  1648252282              2862.673            NaN
# 4  2022-03-25T23:51:23Z  1648252283              2927.541            NaN
#
#    gnss_course  gnss_latitude  gnss_longitude itcs_busRoute  \
# 0          NaN            NaN             NaN             -
# 1          NaN            NaN             NaN             -
# 2          NaN            NaN             NaN             -
# 3          NaN            NaN             NaN             -
# 4          NaN            NaN             NaN             -
#
#    itcs_numberOfPassengers itcs_stopName  ...  odometry_wheelSpeed_mr  \
# 0                      NaN             -  ...                   0.000
# 1                      NaN             -  ...                   0.000
# 2                      NaN             -  ...                   0.000
# 3                      NaN             -  ...                   0.000
# 4                      NaN             -  ...                   0.000
#
#    odometry_wheelSpeed_rl  odometry_wheelSpeed_rr  status_doorIsOpen  \
# 0                   0.000                   0.000                  1
# 1                   0.000                   0.000                  1
# 2                   0.000                   0.000                  1
# 3                   0.000                   0.000                  1
# 4                   0.000                   0.000                  1
#
#    status_gridIsAvailable  status_haltBrakeIsActive  status_parkBrakeIsActive  \
# 0                       0                         1                         1
# 1                       0                         1                         1
# 2                       0                         1                         1
# 3                       0                         1                         1
# 4                       0                         1                         1
#
#    temperature_ambient  traction_brakePressure  traction_tractionForce
# 0              293.839              245833.300                   0.000
# 1              293.461              245833.300                   0.000
# 2              293.150              245833.300                   0.000
# 3              293.839              245833.300                   0.000
# 4              293.461              245833.300                   0.000
#
# [5 rows x 26 columns]

# %%
dataframes['B208_2022-03-25_23-51-19_2022-03-26_03-42-34'].shape
# Out:
# (13876, 26)

# %%
dataframes['B208_2022-03-25_23-51-19_2022-03-26_03-42-34'].dtypes
# Out:
# time_iso                       object
# time_unix                       int64
# electric_powerDemand          float64
# gnss_altitude                 float64
# gnss_course                   float64
# gnss_latitude                 float64
# gnss_longitude                float64
# itcs_busRoute                  object
# itcs_numberOfPassengers       float64
# itcs_stopName                  object
# odometry_articulationAngle    float64
# odometry_steeringAngle        float64
# odometry_vehicleSpeed         float64
# odometry_wheelSpeed_fl        float64
# odometry_wheelSpeed_fr        float64
# odometry_wheelSpeed_ml        float64
# odometry_wheelSpeed_mr        float64
# odometry_wheelSpeed_rl        float64
# odometry_wheelSpeed_rr        float64
# status_doorIsOpen               int64
# status_gridIsAvailable          int64
# status_haltBrakeIsActive        int64
# status_parkBrakeIsActive        int64
# temperature_ambient           float64
# traction_brakePressure        float64
# traction_tractionForce        float64
# dtype: object

# %% [markdown]
# As explained before, `time_iso` should be `datetime` format but instead is `object`. For future analysis it will be better to change the format or to use `time_unix`. The other variables formats are correct for the nature of the variable they represent. I assume this adapts also to the other dataframes.

# %%
diz = defaultdict(int)
# defaultdict(int) initializes the dictionary values to 0

for name in file_names:
    prefix = name[:4]
    diz[prefix] += 1

diz
# Out:
# defaultdict(int, {'B183': 864, 'B208': 545})

# %% [markdown]
# * 864 driving missions with bus 183
# * 545 driving missions with bus 208

# %% [markdown]
# ### Nan values check

# %%
dataframes['B183_2019-04-30_03-18-56_2019-04-30_08-44-20'].isna().sum()
# Out:
# time_iso                          0
# time_unix                         0
# electric_powerDemand              0
# gnss_altitude                 19328
# gnss_course                   19328
# gnss_latitude                 19328
# gnss_longitude                19328
# itcs_busRoute                     0
# itcs_numberOfPassengers       19332
# itcs_stopName                     0
# odometry_articulationAngle        0
# odometry_steeringAngle            0
# odometry_vehicleSpeed             0
# odometry_wheelSpeed_fl            0
# odometry_wheelSpeed_fr            0
# odometry_wheelSpeed_ml            0
# odometry_wheelSpeed_mr            0
# odometry_wheelSpeed_rl            0
# odometry_wheelSpeed_rr            0
# status_doorIsOpen                 0
# status_gridIsAvailable            0
# status_haltBrakeIsActive          0
# status_parkBrakeIsActive          0
# temperature_ambient               0
# traction_brakePressure            0
# traction_tractionForce            0
# dtype: int64

# %%
dataframes['B208_2022-03-25_23-51-19_2022-03-26_03-42-34'].isna().sum()
# Out:
# time_iso                          0
# time_unix                         0
# electric_powerDemand              0
# gnss_altitude                   115
# gnss_course                     110
# gnss_latitude                   110
# gnss_longitude                  110
# itcs_busRoute                     0
# itcs_numberOfPassengers       13781
# itcs_stopName                     0
# odometry_articulationAngle        0
# odometry_steeringAngle            0
# odometry_vehicleSpeed             0
# odometry_wheelSpeed_fl            0
# odometry_wheelSpeed_fr            0
# odometry_wheelSpeed_ml            0
# odometry_wheelSpeed_mr            0
# odometry_wheelSpeed_rl            0
# odometry_wheelSpeed_rr            0
# status_doorIsOpen                 0
# status_gridIsAvailable            0
# status_haltBrakeIsActive          0
# status_parkBrakeIsActive          0
# temperature_ambient               0
# traction_brakePressure            0
# traction_tractionForce            0
# dtype: int64

# %% [markdown]
# In both datasets, it appears that the columns `gnss_altitude`, `gnss_course`, `gnss_latitude`, and `itcs_numberOfPassengers` have some missing values. The number of missing values varies between the two datasets. It might be worth investigating why these specific columns have missing data and how it could impact your analysis or modeling.
#
# Based on this two samples I think that there are missing values for the two columns described above. In future analysis it's important to take in consideration this aspect but also to consider that possible other variables can have Null values because for now I only checked two samples.

# %% [markdown]
# ## 1. Extract all trips with `busRoute` 83

# %% [markdown]
# The variable `busRoute` have some cells with `-` value. `-` can represents the fact that the bus does not stop in a that particular stop. In order to extract the trips with busRoute 83 I decide to transform substitute the values `-` with a null value.

# %%
metadata.head()
# Out:
#                                            name  busNumber  \
# 0  B183_2019-04-30_03-18-56_2019-04-30_08-44-20        183
# 1  B183_2019-04-30_13-22-07_2019-04-30_17-54-02        183
# 2  B183_2019-05-01_05-58-51_2019-05-01_22-32-30        183
# 3  B183_2019-05-03_02-50-21_2019-05-03_05-53-20        183
# 4  B183_2019-05-03_15-41-57_2019-05-03_23-06-24        183
#
#           startTime_iso  startTime_unix           endTime_iso  endTime_unix  \
# 0  2019-04-30T03:18:56Z      1556594336  2019-04-30T08:44:20Z    1556613860
# 1  2019-04-30T13:22:07Z      1556630527  2019-04-30T17:54:02Z    1556646842
# 2  2019-05-01T05:58:51Z      1556690331  2019-05-01T22:32:30Z    1556749950
# 3  2019-05-03T02:50:21Z      1556851821  2019-05-03T05:53:20Z    1556862800
# 4  2019-05-03T15:41:57Z      1556898117  2019-05-03T23:06:24Z    1556924784
#
#    drivenDistance busRoute  energyConsumption  itcs_numberOfPassengers_mean  \
# 0       77213.870        -      478585200.000                         5.539
# 1       59029.600       31      402258500.000                        33.115
# 2      240900.400       33     1445733000.000                        19.689
# 3       42565.480        -      281986700.000                         1.685
# 4      125277.200       72      620725800.000                        23.754
#
#    itcs_numberOfPassengers_min  itcs_numberOfPassengers_max  \
# 0                            0                           20
# 1                            4                           74
# 2                            0                           55
# 3                            0                            8
# 4                            1                           67
#
#    status_gridIsAvailable_mean  temperature_ambient_mean  \
# 0                        0.741                   282.378
# 1                        0.855                   287.544
# 2                        0.778                   288.749
# 3                        0.767                   282.413
# 4                        0.907                   284.733
#
#    temperature_ambient_min  temperature_ambient_max
# 0                  281.150                  293.150
# 1                  285.150                  293.150
# 2                  280.150                  294.150
# 3                  281.150                  292.150
# 4                  282.150                  287.150

# %%
metadata.dtypes
# Out:
# name                             object
# busNumber                         int64
# startTime_iso                    object
# startTime_unix                    int64
# endTime_iso                      object
# endTime_unix                      int64
# drivenDistance                  float64
# busRoute                         object
# energyConsumption               float64
# itcs_numberOfPassengers_mean    float64
# itcs_numberOfPassengers_min       int64
# itcs_numberOfPassengers_max       int64
# status_gridIsAvailable_mean     float64
# temperature_ambient_mean        float64
# temperature_ambient_min         float64
# temperature_ambient_max         float64
# dtype: object

# %%
metadata['busRoute'] = metadata['busRoute'].replace('-', np.nan)

# %%
metadata.head()
# Out:
#                                            name  busNumber  \
# 0  B183_2019-04-30_03-18-56_2019-04-30_08-44-20        183
# 1  B183_2019-04-30_13-22-07_2019-04-30_17-54-02        183
# 2  B183_2019-05-01_05-58-51_2019-05-01_22-32-30        183
# 3  B183_2019-05-03_02-50-21_2019-05-03_05-53-20        183
# 4  B183_2019-05-03_15-41-57_2019-05-03_23-06-24        183
#
#           startTime_iso  startTime_unix           endTime_iso  endTime_unix  \
# 0  2019-04-30T03:18:56Z      1556594336  2019-04-30T08:44:20Z    1556613860
# 1  2019-04-30T13:22:07Z      1556630527  2019-04-30T17:54:02Z    1556646842
# 2  2019-05-01T05:58:51Z      1556690331  2019-05-01T22:32:30Z    1556749950
# 3  2019-05-03T02:50:21Z      1556851821  2019-05-03T05:53:20Z    1556862800
# 4  2019-05-03T15:41:57Z      1556898117  2019-05-03T23:06:24Z    1556924784
#
#    drivenDistance busRoute  energyConsumption  itcs_numberOfPassengers_mean  \
# 0       77213.870      NaN      478585200.000                         5.539
# 1       59029.600       31      402258500.000                        33.115
# 2      240900.400       33     1445733000.000                        19.689
# 3       42565.480      NaN      281986700.000                         1.685
# 4      125277.200       72      620725800.000                        23.754
#
#    itcs_numberOfPassengers_min  itcs_numberOfPassengers_max  \
# 0                            0                           20
# 1                            4                           74
# 2                            0                           55
# 3                            0                            8
# 4                            1                           67
#
#    status_gridIsAvailable_mean  temperature_ambient_mean  \
# 0                        0.741                   282.378
# 1                        0.855                   287.544
# 2                        0.778                   288.749
# 3                        0.767                   282.413
# 4                        0.907                   284.733
#
#    temperature_ambient_min  temperature_ambient_max
# 0                  281.150                  293.150
# 1                  285.150                  293.150
# 2                  280.150                  294.150
# 3                  281.150                  292.150
# 4                  282.150                  287.150

# %%
metadata.isna().sum()
# Out:
# name                             0
# busNumber                        0
# startTime_iso                    0
# startTime_unix                   0
# endTime_iso                      0
# endTime_unix                     0
# drivenDistance                   0
# busRoute                        11
# energyConsumption                0
# itcs_numberOfPassengers_mean     0
# itcs_numberOfPassengers_min      0
# itcs_numberOfPassengers_max      0
# status_gridIsAvailable_mean      0
# temperature_ambient_mean         0
# temperature_ambient_min          0
# temperature_ambient_max          0
# dtype: int64

# %%
print(f'busRoute variable contains: {metadata["busRoute"].isna().sum()} missing values')
# Out:
# busRoute variable contains: 11 missing values

# %%
metadata.dtypes
# Out:
# name                             object
# busNumber                         int64
# startTime_iso                    object
# startTime_unix                    int64
# endTime_iso                      object
# endTime_unix                      int64
# drivenDistance                  float64
# busRoute                         object
# energyConsumption               float64
# itcs_numberOfPassengers_mean    float64
# itcs_numberOfPassengers_min       int64
# itcs_numberOfPassengers_max       int64
# status_gridIsAvailable_mean     float64
# temperature_ambient_mean        float64
# temperature_ambient_min         float64
# temperature_ambient_max         float64
# dtype: object

# %% [markdown]
# Let's check the unique values of `busRoute`.

# %%
metadata['busRoute'].unique()
# Out:
# array([nan, '31', '33', '72', '46', '32', '83', 'N4', 'N2', 'N1'],
#       dtype=object)

# %% [markdown]
# The bus routes are not only integers because there are also `N4`, `N2` and `N1`. Probably this trips correspond to routes done in the night. I can keep the data type as a `object` and the format to `string` and I can extract the trips with busRoute 83.

# %%
metadata_busRoute_83 = metadata[metadata['busRoute']=='83']
metadata_busRoute_83
# Out:
#                                               name  busNumber  \
# 154   B183_2020-03-03_04-42-38_2020-03-03_19-44-51        183
# 155   B183_2020-03-06_04-53-23_2020-03-06_19-44-42        183
#
#       temperature_ambient_mean  temperature_ambient_min  \
# 0                      282.378                  281.150
# 3                      282.413                  281.150
# 9                      287.562                  282.150
# 10                     284.676                  280.150
# 19                     293.144                  283.150
# ...                        ...                      ...
# 1373                   289.255                  288.150
# 1374                   287.349                  285.150
# 1394                   281.388                  280.150
# 1407                   279.454                  277.150
# 1408                   276.004                  273.150
#
#       temperature_ambient_max
# 0                     293.150
# 3                     292.150
# 9                     293.150
# 10                    293.150
# 19                    299.150
# ...                       ...
# 1373                  296.150
# 1374                  295.150
# 1394                  293.150
# 1407                  291.150
# 1408                  291.150
#
# [84 rows x 16 columns]

# %% [markdown]
# `df[~df['column_name'].condition]`
#
# `~` is used to negate the condition. In this case I want to extract the rows whether each value in the `busRoute` column is not numeric using the `str.isnumeric()` method.

# %%
print(f'The number of trips where BusRoute is not Int is: {metadata_busRoute_NotInt.shape[0]}')
# Out:
# The number of trips where BusRoute is not Int is: 84

# %%
# Unique values
metadata_busRoute_NotInt['busRoute'].unique()
# Out:
# array([nan, 'N4', 'N2', 'N1'], dtype=object)

# %% [markdown]
# If I don't want to include Nan values

# %%
metadata_busRoute_NotInt_NotNan = metadata[~metadata['busRoute'].astype(str).str.isnumeric() & ~metadata['busRoute'].isna()]
metadata_busRoute_NotInt_NotNan
# Out:
#                                               name  busNumber  \
# 533   B183_2021-12-18_23-37-00_2021-12-19_03-38-35        183
# 553   B183_2022-01-07_23-40-43_2022-01-08_03-31-21        183
# 554   B183_2022-01-08_23-40-17_2022-01-09_03-35-32        183
# 561   B183_2022-01-15_23-41-46_2022-01-16_03-40-23        183
# 568   B183_2022-01-21_23-35-40_2022-01-22_03-26-24        183
# ...                                            ...        ...
# 1373  B208_2022-10-21_22-38-32_2022-10-22_02-42-21        208
# 1374  B208_2022-10-22_22-34-45_2022-10-23_02-29-59        208
# 1394  B208_2022-11-25_23-35-16_2022-11-26_03-30-39        208
# 1407  B208_2022-12-09_23-55-12_2022-12-10_03-24-28        208
# 1408  B208_2022-12-10_23-34-46_2022-12-11_03-29-05        208
#
#              startTime_iso  startTime_unix           endTime_iso  \
# 533   2021-12-18T23:37:00Z      1639870620  2021-12-19T03:38:35Z
# 553   2022-01-07T23:40:43Z      1641598843  2022-01-08T03:31:21Z
# 554   2022-01-08T23:40:17Z      1641685217  2022-01-09T03:35:32Z
# 561   2022-01-15T23:41:46Z      1642290106  2022-01-16T03:40:23Z
# 568   2022-01-21T23:35:40Z      1642808140  2022-01-22T03:26:24Z
# ...                    ...             ...                   ...
# 1373  2022-10-21T22:38:32Z      1666391912  2022-10-22T02:42:21Z
# 1374  2022-10-22T22:34:45Z      1666478085  2022-10-23T02:29:59Z
# 1394  2022-11-25T23:35:16Z      1669419316  2022-11-26T03:30:39Z
# 1407  2022-12-09T23:55:12Z      1670630112  2022-12-10T03:24:28Z
# 1408  2022-12-10T23:34:46Z      1670715286  2022-12-11T03:29:05Z
#
#       endTime_unix  drivenDistance busRoute  energyConsumption  \
# 533     1639885115       76216.060       N4      481350300.000
# 553     1641612681       68557.060       N2      453625100.000
# 554     1641699332       67962.920       N2      475383300.000
# 561     1642304423       77156.700       N1      525168300.000
# 568     1642821984       71917.750       N2      455476000.000
# ...            ...             ...      ...                ...
# 1373    1666406541       78567.160       N1      434776600.000
# 1374    1666492199       73427.970       N2      399773700.000
# 1394    1669433439       72911.260       N2      447553400.000
# 1407    1670642668       59548.570       N1      451916500.000
# 1408    1670729345       72293.830       N2      535095600.000
#
#       itcs_numberOfPassengers_mean  itcs_numberOfPassengers_min  \
# 533                          9.199                            0
# 553                          4.627                            0
# 554                          7.495                            0
# 561                          6.513                            0
# 568                          5.357                            0
# ...                            ...                          ...
# 1373                        16.333                            0
# 1374                        17.711                            0
# 1394                        11.217                            1
# 1407                        20.105                            0
# 1408                        15.993                            0
#
#       itcs_numberOfPassengers_max  status_gridIsAvailable_mean  \
# 533                            37                        0.492
# 553                            13                        0.427
# 554                            26                        0.516
# 561                            32                        0.474
# 568                            23                        0.494
# ...                           ...                          ...
# 1373                           45                        0.432
# 1374                           57                        0.443
# 1394                           32                        0.465
# 1407                           74                        0.496
# 1408                           52                        0.459
#
#       temperature_ambient_mean  temperature_ambient_min  \
# 533                    276.863                  275.150
# 553                    276.967                  275.150
# 554                    278.565                  277.150
# 561                    274.994                  273.150
# 568                    275.307                  274.150
# ...                        ...                      ...
# 1373                   289.255                  288.150
# 1374                   287.349                  285.150
# 1394                   281.388                  280.150
# 1407                   279.454                  277.150
# 1408                   276.004                  273.150
#
#       temperature_ambient_max
# 533                   288.150
# 553                   287.150
# 554                   288.150
# 561                   286.150
# 568                   281.150
# ...                       ...
# 1373                  296.150
# 1374                  295.150
# 1394                  293.150
# 1407                  291.150
# 1408                  291.150
#
# [73 rows x 16 columns]

# %%
print(f'The number of trips where BusRoute is not Int and is not Nan is: {metadata_busRoute_NotInt_NotNan.shape[0]}')
# Out:
# The number of trips where BusRoute is not Int and is not Nan is: 73

# %%
print(f'The number of trips where BusRoute is Int is: {metadata[metadata["busRoute"].astype(str).str.isnumeric()].shape[0]}')
# Out:
# The number of trips where BusRoute is Int is: 1325

# %% [markdown]
# ## 3. For each (`busNumber`, `busRoute`) pair, determine the number of trips

# %%
metadata['busNumber'].dtypes
# Out:
# dtype('int64')

# %% [markdown]
# `busNumber` is correctly data type integer.
#
# Let's check the unique values.

# %%
metadata['busNumber'].unique()
# Out:
# array([183, 208])

# %% [markdown]
# As expected, since that there are 2 driving missions: 183 and 208, `bus Number` has two values: 183 and 208.

# %% [markdown]
# To answer to this question I consider a dataframe without Nan values (11 rows deleted). I drop the rows with Nan value on `busRoute` column. As checked before `busNumber` does not have missing values.

# %%
metadata_notNan = metadata.dropna()
metadata_notNan
# Out:
#                                               name  busNumber  \
# 1     B183_2019-04-30_13-22-07_2019-04-30_17-54-02        183
# 2     B183_2019-05-01_05-58-51_2019-05-01_22-32-30        183
# 4     B183_2019-05-03_15-41-57_2019-05-03_23-06-24        183
# 5     B183_2019-05-05_07-41-02_2019-05-05_23-20-07        183
# 6     B183_2019-05-06_03-10-43_2019-05-06_19-20-34        183
# ...                                            ...        ...
# 1404  B208_2022-12-06_14-43-49_2022-12-06_18-22-52        208
# 1405  B208_2022-12-07_05-13-02_2022-12-07_19-19-53        208
# 1406  B208_2022-12-08_05-22-20_2022-12-08_18-39-15        208
# 1407  B208_2022-12-09_23-55-12_2022-12-10_03-24-28        208
# 1408  B208_2022-12-10_23-34-46_2022-12-11_03-29-05        208
#
#              startTime_iso  startTime_unix           endTime_iso  \
# 1     2019-04-30T13:22:07Z      1556630527  2019-04-30T17:54:02Z
# 2     2019-05-01T05:58:51Z      1556690331  2019-05-01T22:32:30Z
# 4     2019-05-03T15:41:57Z      1556898117  2019-05-03T23:06:24Z
# 5     2019-05-05T07:41:02Z      1557042062  2019-05-05T23:20:07Z
# 6     2019-05-06T03:10:43Z      1557112243  2019-05-06T19:20:34Z
# ...                    ...             ...                   ...
# 1404  2022-12-06T14:43:49Z      1670337829  2022-12-06T18:22:52Z
# 1405  2022-12-07T05:13:02Z      1670389982  2022-12-07T19:19:53Z
# 1406  2022-12-08T05:22:20Z      1670476940  2022-12-08T18:39:15Z
# 1407  2022-12-09T23:55:12Z      1670630112  2022-12-10T03:24:28Z
# 1408  2022-12-10T23:34:46Z      1670715286  2022-12-11T03:29:05Z
#
#       endTime_unix  drivenDistance busRoute  energyConsumption  \
# 1       1556646842       59029.600       31      402258500.000
# 2       1556749950      240900.400       33     1445733000.000
# 4       1556924784      125277.200       72      620725800.000
# 5       1557098407      283206.900       46     1661700000.000
# 6       1557170434      224131.600       31     1388008000.000
# ...            ...             ...      ...                ...
# 1404    1670350972       51798.780       32      426041900.000
# 1405    1670440793      210041.600       83     1536697000.000
# 1406    1670524755      190372.700       83     1415700000.000
# 1407    1670642668       59548.570       N1      451916500.000
# 1408    1670729345       72293.830       N2      535095600.000
#
#       itcs_numberOfPassengers_mean  itcs_numberOfPassengers_min  \
# 1                           33.115                            4
# 2                           19.689                            0
# 4                           23.754                            1
# 5                           16.499                            0
# 6                           28.035                            0
# ...                            ...                          ...
# 1404                        39.809                            0
# 1405                        28.785                            0
# 1406                        29.879                            0
# 1407                        20.105                            0
# 1408                        15.993                            0
#
#       itcs_numberOfPassengers_max  status_gridIsAvailable_mean  \
# 1                              74                        0.855
# 2                              55                        0.778
# 4                              67                        0.907
# 5                              74                        0.998
# 6                              83                        0.871
# ...                           ...                          ...
# 1404                           83                        0.739
# 1405                          115                        0.435
# 1406                          102                        0.440
# 1407                           74                        0.496
# 1408                           52                        0.459
#
#       temperature_ambient_mean  temperature_ambient_min  \
# 1                      287.544                  285.150
# 2                      288.749                  280.150
# 4                      284.733                  282.150
# 5                      280.167                  277.150
# 6                      282.243                  277.150
# ...                        ...                      ...
# 1404                   279.640                  278.150
# 1405                   279.528                  278.150
# 1406                   279.172                  277.150
# 1407                   279.454                  277.150
# 1408                   276.004                  273.150
#
#       temperature_ambient_max
# 1                     293.150
# 2                     294.150
# 4                     287.150
# 5                     291.150
# 6                     291.150
# ...                       ...
# 1404                  291.150
# 1405                  292.666
# 1406                  292.150
# 1407                  291.150
# 1408                  291.150
#
# [1398 rows x 16 columns]

# %%
metadata_notNan.shape[0]
# Out:
# 1398

# %%
print(f'The number of rows dropped is: {metadata.shape[0] - metadata_notNan.shape[0]}')
# Out:
# The number of rows dropped is: 11

# %% [markdown]
# **Opzione 1**
#
# `('busNumber', 'busRoute')` as a column.

# %%
trips_busNum_busRoute = metadata_notNan.groupby(['busNumber', 'busRoute'], as_index=False).size()

# %%
trips_busNum_busRoute = trips_busNum_busRoute.rename(columns={'size': 'numTrips'})

# %%
trips_busNum_busRoute
# Out:
#     busNumber busRoute  numTrips
# 0         183       31        12
# 1         183       32        12
# 2         183       33       130
# 3         183       46       104
# 4         183       72       114
# 5         183       83       441
# 6         183       N1        10
# 7         183       N2        19
# 8         183       N4        11
# 9         208       31         5
# 10        208       32        14
# 11        208       33        25
# 12        208       46        19
# 13        208       72        44
# 14        208       83       405
# 15        208       N1         6
# 16        208       N2        20
# 17        208       N4         7

# %%
trips_busNum_busRoute['numTrips'].sum()
# Out:
# 1398

# %% [markdown]
# **Opzione 2**
#
# `('busNumber', 'busRoute')` as a index.

# %%
trips_busNum_busRoute_index = metadata_notNan.groupby(['busNumber', 'busRoute']).size()

# %%
trips_busNum_busRoute_index
# Out:
# busNumber  busRoute
# 183        31           12
#            32           12
#            33          130
#            46          104
#            72          114
#            83          441
#            N1           10
#            N2           19
#            N4           11
# 208        31            5
#            32           14
#            33           25
#            46           19
#            72           44
#            83          405
#            N1            6
#            N2           20
#            N4            7
# dtype: int64

# %% [markdown]
# ## 4. For each trip, compute the ratio between the energy consumption and the average number of passengers

# %%
metadata.columns
# Out:
# Index(['name', 'busNumber', 'startTime_iso', 'startTime_unix', 'endTime_iso',
#        'endTime_unix', 'drivenDistance', 'busRoute', 'energyConsumption',
#        'itcs_numberOfPassengers_mean', 'itcs_numberOfPassengers_min',
#        'itcs_numberOfPassengers_max', 'status_gridIsAvailable_mean',
#        'temperature_ambient_mean', 'temperature_ambient_min',
#        'temperature_ambient_max'],
#       dtype='object')

# %% [markdown]
# The ratio between energy consumption and the average number of passenger can be calculated in the following way:
# `energyConsumption` / `itcs_numberOfPassengers_mean` which represents the ratio of energy consumption per passenger on average.

# %%
metadata['ratio_EnergCons_MeanNumOfPass'] = metadata['energyConsumption'] / metadata['itcs_numberOfPassengers_mean']

# %%
metadata[['name', 'energyConsumption', 'itcs_numberOfPassengers_mean', 'ratio_EnergCons_MeanNumOfPass']].head()
# Out:
#                                            name  energyConsumption  \
# 0  B183_2019-04-30_03-18-56_2019-04-30_08-44-20      478585200.000
# 1  B183_2019-04-30_13-22-07_2019-04-30_17-54-02      402258500.000
# 2  B183_2019-05-01_05-58-51_2019-05-01_22-32-30     1445733000.000
# 3  B183_2019-05-03_02-50-21_2019-05-03_05-53-20      281986700.000
# 4  B183_2019-05-03_15-41-57_2019-05-03_23-06-24      620725800.000
#
#    itcs_numberOfPassengers_mean  ratio_EnergCons_MeanNumOfPass
# 0                         5.539                   86405000.307
# 1                        33.115                   12147474.013
# 2                        19.689                   73427940.479
# 3                         1.685                  167332785.421
# 4                        23.754                   26131895.121

# %% [markdown]
# **Comment on first row values**
#
# * `energyConsumption`: The energy consumption for the first bus trip is approximately 479,585,200.
# * `itcs_numberOfPassengers_mean`: The average number of passengers for the first bus trip is approximately 5.54.
# * `ratio_EnergCons_MeanNumOfPass`: The ratio of energy consumption per average number of passengers is a derived metric that helps assess the energy efficiency of a bus trip. In this context, the value of approximately 86,405,000 suggests that, on average, each passenger contributes to an energy consumption of about 86.4 million units during this particular bus trip. This ratio provides insights into the energy efficiency of the transportation system, with lower values indicating more efficient energy utilization per passenger.
#
# The ratio tends to increase when the average number of passengers is lower. The higher ratio in situations with fewer passengers may indicate a relatively less efficient use of energy resources per passenger, emphasizing the potential benefits of improving passenger occupancy for enhanced energy.

# %% [markdown]
# ## 5. For each station (`itcs_stopName`), determine the average number of passengers.

# %% [markdown]
# The information `itcs_stopName` is a variable included in each dataframe of `dataframes` dictionary.  `itcs_stopName` can include the symbol `-` because, as before, probably the bus didn't stop in that stop. In this situation I consider in a missing value and I replace with Nan.

# %%
dataframes['B208_2022-03-25_23-51-19_2022-03-26_03-42-34'].columns
# Out:
# Index(['time_iso', 'time_unix', 'electric_powerDemand', 'gnss_altitude',
#        'gnss_course', 'gnss_latitude', 'gnss_longitude', 'itcs_busRoute',
#        'itcs_numberOfPassengers', 'itcs_stopName',
#        'odometry_articulationAngle', 'odometry_steeringAngle',
#        'odometry_vehicleSpeed', 'odometry_wheelSpeed_fl',
#        'odometry_wheelSpeed_fr', 'odometry_wheelSpeed_ml',
#        'odometry_wheelSpeed_mr', 'odometry_wheelSpeed_rl',
#        'odometry_wheelSpeed_rr', 'status_doorIsOpen', 'status_gridIsAvailable',
#        'status_haltBrakeIsActive', 'status_parkBrakeIsActive',
#        'temperature_ambient', 'traction_brakePressure',
#        'traction_tractionForce'],
#       dtype='object')

# %%
dataframes['B208_2022-03-25_23-51-19_2022-03-26_03-42-34']['itcs_stopName'].unique()
# Out:
# array(['-', 'Zürich, Bahnhofplatz/HB', 'Zürich, Löwenplatz',
#        'Zürich, Sihlpost / HB', 'Zürich, Kanonengasse',
#        'Zürich, Militär-/Langstrasse', 'Zürich, Bäckeranlage',
#        'Zürich, Güterbahnhof', 'Zürich, Hardplatz',
#        'Zürich, Herdernstrasse', 'Zürich, SBB-Werkstätte',
#        'Zürich, Letzipark', 'Zürich, Letzibach',
#        'Zürich, Bahnhof Altstetten', 'Zürich, Bristenstrasse',
#        'Zürich, Lindenplatz', 'Zürich, Rautistrasse',
#        'Zürich, Schulhaus Buchlern', 'Zürich, Rautihalde',
#        'Zürich, Salzweg', 'Zürich, Dunkelhölzli', 'Zürich, Sihlquai/HB',
#        'Zürich, Museum für Gestaltung', 'Zürich, Limmatplatz',
#        'Zürich, Quellenstrasse', 'Zürich, Löwenbräu',
#        'Zürich, Escher-Wyss-Platz', 'Zürich, Rosengartenstrasse',
#        'Zürich, Lehenstrasse', 'Zürich, Rebbergsteig',
#        'Zürich, Kempfhofsteig', 'Zürich, Schwert',
#        'Zürich, Meierhofplatz', 'Zürich, Wieslergasse',
#        'Zürich, Singlistrasse', 'Zürich, Segantinistrasse',
#        'Zürich, Giblenstrasse', 'Zürich, Heizenholz',
#        'Zürich, Geeringstrasse', 'Zürich, Rütihof'], dtype=object)

# %%
dataframes['B208_2022-03-25_23-51-19_2022-03-26_03-42-34']['itcs_numberOfPassengers'].unique()
# Out:
# array([nan, 46., 55., 60., 67., 42., 40., 37., 43., 41., 19., 13.,  6.,
#         5.,  0.,  2.,  4.,  7., 12., 14., 45.,  9., 17., 11.,  8.,  3.,
#         1., 15., 16.])

# %% [markdown]
# The stops per trip changes. The first step is calculating the number of passenger per stop for every trip. We store this information in `dataframes_Stop_NumPass` dictionary. Later we create another dictonary with the sum of passenger per stops considering all the trips. Finally we will do the average.

# %%
for trip, df in dataframes.items():
    df['itcs_stopName'] = df['itcs_stopName'].replace('-', np.nan)
    df['Bus_identifier'] = trip # define bus identifier variable

# %%
# Concatenate all dataframes into a single dataframe
all_df = pd.concat(dataframes.values(), ignore_index=True)

# %%
all_df
# Out:
#                       time_iso   time_unix  electric_powerDemand  \
# 0         2020-11-13T14:52:45Z  1605279165              9346.241
# 1         2020-11-13T14:52:46Z  1605279166              9819.954
# 2         2020-11-13T14:52:47Z  1605279167              9023.815
# 3         2020-11-13T14:52:48Z  1605279168              9187.615
# 4         2020-11-13T14:52:49Z  1605279169              9960.241
# ...                        ...         ...                   ...
# 48674457  2022-01-27T08:11:21Z  1643271081                -0.327
# 48674458  2022-01-27T08:11:22Z  1643271082                -0.645
# 48674459  2022-01-27T08:11:23Z  1643271083                -0.806
# 48674460  2022-01-27T08:11:24Z  1643271084                -0.803
# 48674461  2022-01-27T08:11:25Z  1643271085                -0.725
#
#           gnss_altitude  gnss_course  gnss_latitude  gnss_longitude  \
# 0                   NaN          NaN            NaN             NaN
# 1                   NaN          NaN            NaN             NaN
# 2                   NaN          NaN            NaN             NaN
# 3                   NaN          NaN            NaN             NaN
# 4               429.200        1.560          0.827           0.148
# ...                 ...          ...            ...             ...
# 48674457            NaN          NaN            NaN             NaN
# 48674458            NaN          NaN            NaN             NaN
# 48674459            NaN          NaN            NaN             NaN
# 48674460            NaN          NaN            NaN             NaN
# 48674461            NaN          NaN            NaN             NaN
#
#          itcs_busRoute  itcs_numberOfPassengers itcs_stopName  ...  \
# 0                    -                      NaN           NaN  ...
# 1                    -                      NaN           NaN  ...
# 2                    -                      NaN           NaN  ...
# 3                    -                      NaN           NaN  ...
# 4                    -                      NaN           NaN  ...
# ...                ...                      ...           ...  ...
# 48674457             -                      NaN           NaN  ...
# 48674458             -                      NaN           NaN  ...
# 48674459             -                      NaN           NaN  ...
# 48674460             -                      NaN           NaN  ...
# 48674461             -                      NaN           NaN  ...
#
#           odometry_wheelSpeed_rl  odometry_wheelSpeed_rr  status_doorIsOpen  \
# 0                          0.000                   0.000              1.000
# 1                          0.000                   0.000              1.000
# 2                          0.000                   0.000              1.000
# 3                          0.000                   0.000              1.000
# 4                          0.000                   0.000              1.000
# ...                          ...                     ...                ...
# 48674457                   0.000                   0.000              1.000
# 48674458                   0.000                   0.000              1.000
# 48674459                   0.000                   0.000              1.000
# 48674460                   0.000                   0.000              1.000
# 48674461                   0.000                   0.000              1.000
#
#           status_gridIsAvailable  status_haltBrakeIsActive  \
# 0                          0.000                     1.000
# 1                          0.000                     1.000
# 2                          0.000                     1.000
# 3                          0.000                     1.000
# 4                          0.000                     1.000
# ...                          ...                       ...
# 48674457                   0.000                     0.000
# 48674458                   0.000                     0.000
# 48674459                   0.000                     0.000
# 48674460                   0.000                     0.000
# 48674461                   0.000                     0.000
#
#           status_parkBrakeIsActive  temperature_ambient  \
# 0                            0.000              292.150
# 1                            0.000              292.150
# 2                            0.000              292.150
# 3                            0.000              292.150
# 4                            0.000              292.150
# ...                            ...                  ...
# 48674457                     1.000              276.150
# 48674458                     1.000              276.150
# 48674459                     1.000              276.150
# 48674460                     1.000              276.150
# 48674461                     1.000              276.150
#
#           traction_brakePressure  traction_tractionForce  \
# 0                     856666.700                   0.000
# 1                     860000.000                   0.000
# 2                     861947.100                   0.000
# 3                     865000.000                   0.000
# 4                     870000.000                   0.000
# ...                          ...                     ...
# 48674457                   0.000                   0.000
# 48674458                   0.000                   0.000
# 48674459                   0.000                   0.000
# 48674460                   0.000                   0.000
# 48674461                   0.000                   0.000
#
#                                         Bus_identifier
# 0         B183_2020-11-13_14-52-45_2020-11-13_19-13-45
# 1         B183_2020-11-13_14-52-45_2020-11-13_19-13-45
# 2         B183_2020-11-13_14-52-45_2020-11-13_19-13-45
# 3         B183_2020-11-13_14-52-45_2020-11-13_19-13-45
# 4         B183_2020-11-13_14-52-45_2020-11-13_19-13-45
# ...                                                ...
# 48674457  B183_2022-01-27_03-51-06_2022-01-27_08-11-25
# 48674458  B183_2022-01-27_03-51-06_2022-01-27_08-11-25
# 48674459  B183_2022-01-27_03-51-06_2022-01-27_08-11-25
# 48674460  B183_2022-01-27_03-51-06_2022-01-27_08-11-25
# 48674461  B183_2022-01-27_03-51-06_2022-01-27_08-11-25
#
# [48674462 rows x 27 columns]

# %%
# save all_df to csv
all_df.to_csv("/Users/veronicamorelli/Desktop/University/Foundations of Computer Science/all_df.csv", index=False)

# %%
# Group by 'itcs_stopName' and calculate the average number of passengers
average_passengers_per_stop = all_df.groupby('itcs_stopName')['itcs_numberOfPassengers'].mean().reset_index()

# %%
average_passengers_per_stop
# Out:
#                       itcs_stopName  itcs_numberOfPassengers
# 0                 Zürich, Albisrank                   16.197
# 1          Zürich, Albisriederplatz                   25.453
# 2         Zürich, Altes Krematorium                   21.980
# 3         Zürich, Bahnhof Affoltern                    2.851
# 4        Zürich, Bahnhof Altstetten                    7.817
# ..                              ...                      ...
# 144         Zürich, Zentrum Witikon                   17.255
# 145        Zürich, Zweiackerstrasse                    7.502
# 146              Zürich, Zwielplatz                    2.049
# 147             Zürich, Zwinglihaus                   23.197
# 148  Zürich,Kalkbreite/Bhf.Wiedikon                   23.161
#
# [149 rows x 2 columns]

# %% [markdown]
# ## 6. For each station, determine the buses that have stopped there at least once.

# %%
# Create new column with bus number
all_df['Bus_number'] = all_df['Bus_identifier'].str.extract(r'B(\d+)_')
all_df.head()
# Out:
#                time_iso   time_unix  electric_powerDemand  gnss_altitude  \
# 0  2020-11-13T14:52:45Z  1605279165              9346.241            NaN
# 1  2020-11-13T14:52:46Z  1605279166              9819.954            NaN
# 2  2020-11-13T14:52:47Z  1605279167              9023.815            NaN
# 3  2020-11-13T14:52:48Z  1605279168              9187.615            NaN
# 4  2020-11-13T14:52:49Z  1605279169              9960.241        429.200
#
#    gnss_course  gnss_latitude  gnss_longitude itcs_busRoute  \
# 0          NaN            NaN             NaN             -
# 1          NaN            NaN             NaN             -
# 2          NaN            NaN             NaN             -
# 3          NaN            NaN             NaN             -
# 4        1.560          0.827           0.148             -
#
#    itcs_numberOfPassengers itcs_stopName  ...  odometry_wheelSpeed_rr  \
# 0                      NaN           NaN  ...                   0.000
# 1                      NaN           NaN  ...                   0.000
# 2                      NaN           NaN  ...                   0.000
# 3                      NaN           NaN  ...                   0.000
# 4                      NaN           NaN  ...                   0.000
#
#    status_doorIsOpen  status_gridIsAvailable  status_haltBrakeIsActive  \
# 0              1.000                   0.000                     1.000
# 1              1.000                   0.000                     1.000
# 2              1.000                   0.000                     1.000
# 3              1.000                   0.000                     1.000
# 4              1.000                   0.000                     1.000
#
#    status_parkBrakeIsActive  temperature_ambient  traction_brakePressure  \
# 0                     0.000              292.150              856666.700
# 1                     0.000              292.150              860000.000
# 2                     0.000              292.150              861947.100
# 3                     0.000              292.150              865000.000
# 4                     0.000              292.150              870000.000
#
#    traction_tractionForce                                Bus_identifier  \
# 0                   0.000  B183_2020-11-13_14-52-45_2020-11-13_19-13-45
# 1                   0.000  B183_2020-11-13_14-52-45_2020-11-13_19-13-45
# 2                   0.000  B183_2020-11-13_14-52-45_2020-11-13_19-13-45
# 3                   0.000  B183_2020-11-13_14-52-45_2020-11-13_19-13-45
# 4                   0.000  B183_2020-11-13_14-52-45_2020-11-13_19-13-45
#
#    Bus_number
# 0         183
# 1         183
# 2         183
# 3         183
# 4         183
#
# [5 rows x 28 columns]

# %% [markdown]
# * `B`: This matches the literal character 'B'.
# * `(\d+)`: This is a capturing group that matches one or more digits (\d+). The parentheses () are used to capture the matched digits.
# * `_`: This matches the literal underscore character.

# %%
all_df.columns
# Out:
# Index(['time_iso', 'time_unix', 'electric_powerDemand', 'gnss_altitude',
#        'gnss_course', 'gnss_latitude', 'gnss_longitude', 'itcs_busRoute',
#        'itcs_numberOfPassengers', 'itcs_stopName',
#        'odometry_articulationAngle', 'odometry_steeringAngle',
#        'odometry_vehicleSpeed', 'odometry_wheelSpeed_fl',
#        'odometry_wheelSpeed_fr', 'odometry_wheelSpeed_ml',
#        'odometry_wheelSpeed_mr', 'odometry_wheelSpeed_rl',
#        'odometry_wheelSpeed_rr', 'status_doorIsOpen', 'status_gridIsAvailable',
#        'status_haltBrakeIsActive', 'status_parkBrakeIsActive',
#        'temperature_ambient', 'traction_brakePressure',
#        'traction_tractionForce', 'Bus_identifier', 'Bus_number'],
#       dtype='object')

# %%
station_buses_iden = all_df.groupby(['itcs_stopName', 'Bus_identifier'], as_index=False).size()
station_buses_iden
# Out:
#                         itcs_stopName  \
# 0                   Zürich, Albisrank
# 1                   Zürich, Albisrank
# 2                   Zürich, Albisrank
# 3                   Zürich, Albisrank
# 4                   Zürich, Albisrank
# ...                               ...
# 34320  Zürich,Kalkbreite/Bhf.Wiedikon
# 34321  Zürich,Kalkbreite/Bhf.Wiedikon
# 34322  Zürich,Kalkbreite/Bhf.Wiedikon
# 34323  Zürich,Kalkbreite/Bhf.Wiedikon
# 34324  Zürich,Kalkbreite/Bhf.Wiedikon
#
#                                      Bus_identifier  size
# 0      B183_2020-03-03_04-42-38_2020-03-03_19-44-51    20
# 1      B183_2020-03-06_04-53-23_2020-03-06_19-44-42    29
# 2      B183_2020-03-09_14-16-13_2020-03-09_19-34-17     8
# 3      B183_2020-03-10_04-50-03_2020-03-10_19-51-25    24
# 4      B183_2020-03-12_04-56-41_2020-03-12_19-44-57    25
# ...                                             ...   ...
# 34320  B208_2022-10-22_22-34-45_2022-10-23_02-29-59     3
# 34321  B208_2022-11-16_14-44-04_2022-11-16_18-00-11     4
# 34322  B208_2022-11-25_23-35-16_2022-11-26_03-30-39     2
# 34323  B208_2022-12-06_14-43-49_2022-12-06_18-22-52     4
# 34324  B208_2022-12-10_23-34-46_2022-12-11_03-29-05     4
#
# [34325 rows x 3 columns]

# %%
station_buses_num = all_df.groupby(['itcs_stopName', 'Bus_number'], as_index=False).size()
station_buses_num
# Out:
#                       itcs_stopName Bus_number   size
# 0                 Zürich, Albisrank        183   6324
# 1                 Zürich, Albisrank        208   6199
# 2          Zürich, Albisriederplatz        183  11218
# 3          Zürich, Albisriederplatz        208   7633
# 4         Zürich, Altes Krematorium        183  10022
# ..                              ...        ...    ...
# 292              Zürich, Zwielplatz        208      4
# 293             Zürich, Zwinglihaus        183   2791
# 294             Zürich, Zwinglihaus        208   1231
# 295  Zürich,Kalkbreite/Bhf.Wiedikon        183    279
# 296  Zürich,Kalkbreite/Bhf.Wiedikon        208    256
#
# [297 rows x 3 columns]

# %% [markdown]
# ## 7. For each station, determine the buses that have stopped there at least ten times.

# %%
station_buses10 = station_buses_num[station_buses_num['size'] >=10]
station_buses10
# Out:
#                       itcs_stopName Bus_number   size
# 0                 Zürich, Albisrank        183   6324
# 1                 Zürich, Albisrank        208   6199
# 2          Zürich, Albisriederplatz        183  11218
# 3          Zürich, Albisriederplatz        208   7633
# 4         Zürich, Altes Krematorium        183  10022
# ..                              ...        ...    ...
# 291              Zürich, Zwielplatz        183     77
# 293             Zürich, Zwinglihaus        183   2791
# 294             Zürich, Zwinglihaus        208   1231
# 295  Zürich,Kalkbreite/Bhf.Wiedikon        183    279
# 296  Zürich,Kalkbreite/Bhf.Wiedikon        208    256
#
# [295 rows x 3 columns]

# %%
station_buses10_iden = station_buses_iden[station_buses_iden['size'] >=10]
station_buses10_iden
# Out:
#                         itcs_stopName  \
# 0                   Zürich, Albisrank
# 1                   Zürich, Albisrank
# 3                   Zürich, Albisrank
# 4                   Zürich, Albisrank
# 5                   Zürich, Albisrank
# ...                               ...
# 34306  Zürich,Kalkbreite/Bhf.Wiedikon
# 34313  Zürich,Kalkbreite/Bhf.Wiedikon
# 34314  Zürich,Kalkbreite/Bhf.Wiedikon
# 34315  Zürich,Kalkbreite/Bhf.Wiedikon
# 34316  Zürich,Kalkbreite/Bhf.Wiedikon
#
#                                      Bus_identifier  size
# 0      B183_2020-03-03_04-42-38_2020-03-03_19-44-51    20
# 1      B183_2020-03-06_04-53-23_2020-03-06_19-44-42    29
# 3      B183_2020-03-10_04-50-03_2020-03-10_19-51-25    24
# 4      B183_2020-03-12_04-56-41_2020-03-12_19-44-57    25
# 5      B183_2020-03-13_04-55-14_2020-03-13_12-05-52    15
# ...                                             ...   ...
# 34306  B208_2022-05-31_14-02-18_2022-05-31_21-10-17    10
# 34313  B208_2022-07-21_03-38-27_2022-07-21_22-42-15    28
# 34314  B208_2022-07-24_02-43-32_2022-07-24_22-54-18    30
# 34315  B208_2022-08-03_04-01-44_2022-08-03_18-51-01    20
# 34316  B208_2022-08-18_02-46-22_2022-08-18_23-06-16    29
#
# [17642 rows x 3 columns]

# %% [markdown]
# ## 8. For each (route, bus) pair, compute the ratio between the overall energy consumption and the overall driven distance.

# %%
metadata.columns
# Out:
# Index(['name', 'busNumber', 'startTime_iso', 'startTime_unix', 'endTime_iso',
#        'endTime_unix', 'drivenDistance', 'busRoute', 'energyConsumption',
#        'itcs_numberOfPassengers_mean', 'itcs_numberOfPassengers_min',
#        'itcs_numberOfPassengers_max', 'status_gridIsAvailable_mean',
#        'temperature_ambient_mean', 'temperature_ambient_min',
#        'temperature_ambient_max', 'ratio_EnergCons_MeanNumOfPass',
#        'ratio_EnergCons_DrivDist'],
#       dtype='object')

# %%
# Compute overall Energy consumption and overall Driven distance
group_metadata_sum = metadata.groupby(['busRoute', 'name'], as_index=False)[['energyConsumption', 'drivenDistance']].sum()
group_metadata_sum
# Out:
#      busRoute                                          name  \
# 0          31  B183_2019-04-30_13-22-07_2019-04-30_17-54-02
# 1          31  B183_2019-05-06_03-10-43_2019-05-06_19-20-34
# 2          31  B183_2019-12-05_16-02-38_2019-12-05_23-57-34
# 3          31  B183_2020-11-16_15-02-32_2020-11-17_00-01-27
# 4          31  B183_2021-04-19_02-53-42_2021-04-19_10-35-39
# ...       ...                                           ...
# 1393       N4  B208_2022-01-21_23-52-47_2022-01-22_03-39-46
# 1394       N4  B208_2022-04-01_22-29-37_2022-04-02_02-35-00
# 1395       N4  B208_2022-04-23_22-40-20_2022-04-24_02-36-05
# 1396       N4  B208_2022-06-17_22-38-03_2022-06-18_02-37-46
# 1397       N4  B208_2022-10-15_22-48-49_2022-10-16_02-46-32
#
#       energyConsumption  drivenDistance
# 0         402258500.000       59029.600
# 1        1388008000.000      224131.600
# 2         950027900.000      113737.900
# 3         792612200.000      121621.700
# 4         753582100.000      107712.700
# ...                 ...             ...
# 1393      480832900.000       75349.670
# 1394      554833400.000       78118.890
# 1395      455813800.000       76776.520
# 1396      371598500.000       78130.690
# 1397      365690800.000       76038.860
#
# [1398 rows x 4 columns]

# %%
# Calculate the ratio
group_metadata_sum['Ratio_EnergCons_DrivDist'] = group_metadata_sum['energyConsumption'] / group_metadata_sum['drivenDistance']

# %%
group_metadata_sum
# Out:
#      busRoute                                          name  \
# 0          31  B183_2019-04-30_13-22-07_2019-04-30_17-54-02
# 1          31  B183_2019-05-06_03-10-43_2019-05-06_19-20-34
# 2          31  B183_2019-12-05_16-02-38_2019-12-05_23-57-34
# 3          31  B183_2020-11-16_15-02-32_2020-11-17_00-01-27
# 4          31  B183_2021-04-19_02-53-42_2021-04-19_10-35-39
# ...       ...                                           ...
# 1393       N4  B208_2022-01-21_23-52-47_2022-01-22_03-39-46
# 1394       N4  B208_2022-04-01_22-29-37_2022-04-02_02-35-00
# 1395       N4  B208_2022-04-23_22-40-20_2022-04-24_02-36-05
# 1396       N4  B208_2022-06-17_22-38-03_2022-06-18_02-37-46
# 1397       N4  B208_2022-10-15_22-48-49_2022-10-16_02-46-32
#
#       energyConsumption  drivenDistance  Ratio_EnergCons_DrivDist
# 0         402258500.000       59029.600                  6814.522
# 1        1388008000.000      224131.600                  6192.826
# 2         950027900.000      113737.900                  8352.782
# 3         792612200.000      121621.700                  6517.029
# 4         753582100.000      107712.700                  6996.223
# ...                 ...             ...                       ...
# 1393      480832900.000       75349.670                  6381.354
# 1394      554833400.000       78118.890                  7102.423
# 1395      455813800.000       76776.520                  5936.891
# 1396      371598500.000       78130.690                  4756.114
# 1397      365690800.000       76038.860                  4809.262
#
# [1398 rows x 5 columns]

# %% [markdown]
# ### Comment first row data
#
# | busRoute | name                                           | energyConsumption | drivenDistance | Ratio_EnergCons_DrivDist |
# |----------|------------------------------------------------|-------------------|-----------------|---------------------------|
# | 31       | B183_2019-04-30_13-22-07_2019-04-30_17-54-02 | 402,258,500.000  | 59,029.600      | 6,814.522                 |
#
#
# * `busRoute`: The route number associated with the bus.
# * `name`: The unique identifier for the bus, including a timestamp.
# * `energyConsumption`: The total energy consumption by the bus on the specified route and time period.
# * `drivenDistance`: The total distance driven by the bus on the specified route and time period.
# * `Ratio_EnergCons_DrivDist`: This column represents the ratio between the overall energy consumption (energyConsumption) and the overall driven distance (drivenDistance) for the specific bus on the given route and time period. In this case, the ratio is calculated as 6814.522, indicating that for every unit of distance driven, the bus consumed approximately 6814.522 units of energy.
#
# The `Ratio_EnergCons_DrivDist` column provides insight into the efficiency of the bus in terms of energy consumption relative to the distance it has traveled. A higher ratio suggests higher energy consumption per unit distance, while a lower ratio indicates better energy efficiency.

# %% [markdown]
# ## 9. Starting from the results of the previous point, for each route compute the buses with max and min energy ratio, and save the difference between these ratios in a dataframe.

# %%
group_metadata_sum.groupby('busRoute')['Ratio_EnergCons_DrivDist'].idxmin()
# Out:
# busRoute
# 31      16
# 32      20
# 33     181
# 46     278
# 72     469
# 83    1073
# N1    1338
# N2    1353
# N4    1396
# Name: Ratio_EnergCons_DrivDist, dtype: int64

# %%
group_metadata_sum.groupby('busRoute')['Ratio_EnergCons_DrivDist'].min()
# Out:
# busRoute
# 31   4779.099
# 32   4718.151
# 33   4124.415
# 46   4260.347
# 72   4302.356
# 83   4032.769
# N1   4617.548
# N2   3932.347
# N4   4756.114
# Name: Ratio_EnergCons_DrivDist, dtype: float64

# %%
group_metadata_sum.groupby('busRoute')['Ratio_EnergCons_DrivDist'].idxmax()
# Out:
# busRoute
# 31       2
# 32      42
# 33     172
# 46     236
# 72     434
# 83     601
# N1    1340
# N2    1379
# N4    1390
# Name: Ratio_EnergCons_DrivDist, dtype: int64

# %%
group_metadata_sum.groupby('busRoute')['Ratio_EnergCons_DrivDist'].max()
# Out:
# busRoute
# 31   8352.782
# 32   8224.941
# 33   8135.999
# 46   7930.619
# 72   8655.515
# 83   8542.956
# N1   7589.040
# N2   7401.677
# N4   7137.138
# Name: Ratio_EnergCons_DrivDist, dtype: float64

# %%
Ratio_EnergCons_DrivDist_min = group_metadata_sum.iloc[group_metadata_sum.groupby('busRoute')['Ratio_EnergCons_DrivDist'].idxmin(),:] 
Ratio_EnergCons_DrivDist_min = Ratio_EnergCons_DrivDist_min.rename(columns={'Ratio_EnergCons_DrivDist': 'Ratio_EnergCons_DrivDist_min'})
Ratio_EnergCons_DrivDist_min
# Out:
#      busRoute                                          name  \
# Out:
# busRoute                                                                   83
# name                             B183_2020-12-01_14-28-08_2020-12-01_19-39-08
# energyConsumption                                               669719600.000
# drivenDistance                                                      78394.360
# Ratio_EnergCons_DrivDist_max                                         8542.956
# Ratio_EnergCons_DrivDist_min                                         4032.769
# Ratio_EnergCons_DrivDist_diff                                        4510.188
# Name: 5, dtype: object

# %% [markdown]
# ## 11. Extract the rows of the details such that the `gnss_altitude` differs from the value in the preceding row. Store also the difference in the variable `altitude_variation`.

# %% [markdown]
# I can use `dataframes` because I want to work on each detail.

# %%
dataframes_filtered = {}
for trip, df in dataframes.items():
    df['altitude_variation'] = df['gnss_altitude'].diff()
    dataframes_filtered[trip] = df[df['altitude_variation'].notna()]

# %%
dataframes_filtered['B183_2019-04-30_03-18-56_2019-04-30_08-44-20']
# Out:
#                  time_iso   time_unix  electric_powerDemand  gnss_altitude  \
# 143  2019-04-30T03:21:19Z  1556594479             17476.710        397.800
# 144  2019-04-30T03:21:20Z  1556594480             17800.860        397.800
# 145  2019-04-30T03:21:21Z  1556594481              4461.355        397.800
# 146  2019-04-30T03:21:22Z  1556594482             28584.730        397.800
# 147  2019-04-30T03:21:23Z  1556594483             31207.220        397.800
# ..                    ...         ...                   ...            ...
# 376  2019-04-30T03:25:12Z  1556594712             28578.890        399.597
# 377  2019-04-30T03:25:13Z  1556594713             27972.820        399.395
# 378  2019-04-30T03:25:14Z  1556594714             28028.800        399.095
# 379  2019-04-30T03:25:15Z  1556594715             28376.830        398.797
# 380  2019-04-30T03:25:16Z  1556594716             27947.400        398.602
#
#      gnss_course  gnss_latitude  gnss_longitude itcs_busRoute  \
# 143        1.433          0.827           0.148             -
# 144        1.433          0.827           0.148             -
# 145        1.433          0.827           0.148             -
# 146        1.433          0.827           0.148             -
# 147        1.433          0.827           0.148             -
# ..           ...            ...             ...           ...
# 376        2.136          0.827           0.149             -
# 377        2.143          0.827           0.149             -
# 378        2.154          0.827           0.149             -
# 379        2.154          0.827           0.149             -
# 380        2.124          0.827           0.149             -
#
#      itcs_numberOfPassengers itcs_stopName  ...  odometry_wheelSpeed_rr  \
# 143                      NaN           NaN  ...                   3.146
# 144                      NaN           NaN  ...                   3.234
# 145                      NaN           NaN  ...                   3.168
# 146                      NaN           NaN  ...                   3.236
# 147                      NaN           NaN  ...                   3.452
# ..                       ...           ...  ...                     ...
# 376                      NaN           NaN  ...                   0.000
# 377                      NaN           NaN  ...                   0.000
# 378                      NaN           NaN  ...                   0.000
# 379                      NaN           NaN  ...                   0.000
# 380                      NaN           NaN  ...                   0.000
#
#      status_doorIsOpen  status_gridIsAvailable  status_haltBrakeIsActive  \
# 143                  0                       1                         0
# 144                  0                       1                         0
# 145                  0                       1                         0
# 146                  0                       1                         0
# 147                  0                       1                         0
# ..                 ...                     ...                       ...
# 376                  0                       1                         0
# 377                  0                       1                         0
# 378                  0                       1                         0
# 379                  0                       1                         0
# 380                  1                       1                         0
#
#      status_parkBrakeIsActive  temperature_ambient  traction_brakePressure  \
# 143                         0              292.150                   0.000
# 144                         0              292.150                   0.000
# 145                         0              292.150                   0.000
# 146                         0              292.150                   0.000
# 147                         0              292.150                   0.000
# ..                        ...                  ...                     ...
# 376                         0              287.150              119629.600
# 377                         0              287.150              245646.200
# 378                         0              287.150              245651.000
# 379                         0              287.150              244819.600
# 380                         0              287.150              244166.700
#
#      traction_tractionForce                                Bus_identifier  \
# 143                3621.687  B183_2019-04-30_03-18-56_2019-04-30_08-44-20
#
#  'B183_2019-04-30_03-18-56_2019-04-30_08-44-20': 184.73890000000063,
#  'B208_2022-01-18_05-17-03_2022-01-18_19-04-10': 8976.9649,
#  'B208_2021-09-13_04-10-03_2021-09-13_18-22-31': 9071.359099999998,
#  'B208_2022-10-18_13-42-01_2022-10-18_23-03-19': 7602.4746000000005,
#  'B208_2022-09-28_03-48-36_2022-09-28_18-42-53': 9319.313199999999,
#  'B183_2022-08-06_04-54-18_2022-08-06_23-12-01': 28262.42100000001,
#  'B208_2022-09-21_04-05-16_2022-09-21_18-20-09': 8893.179399999995,
#  ...}

# %% [markdown]
# ## 13.  For each month of the year, compute the average ambient temperature

# %%
all_df = pd.read_csv(config['path_ZTbus_alldf'])
all_df.head()
# Out:
#                time_iso   time_unix  electric_powerDemand  gnss_altitude  \
# 0  2020-11-13T14:52:45Z  1605279165              9346.241            NaN
# 1  2020-11-13T14:52:46Z  1605279166              9819.954            NaN
# 2  2020-11-13T14:52:47Z  1605279167              9023.815            NaN
# 3  2020-11-13T14:52:48Z  1605279168              9187.615            NaN
# 4  2020-11-13T14:52:49Z  1605279169              9960.241        429.200
#
#    gnss_course  gnss_latitude  gnss_longitude itcs_busRoute  \
# 0          NaN            NaN             NaN             -
# 1          NaN            NaN             NaN             -
# 2          NaN            NaN             NaN             -
# 3          NaN            NaN             NaN             -
# 4        1.560          0.827           0.148             -
#
#    itcs_numberOfPassengers itcs_stopName  ...  odometry_wheelSpeed_rl  \
# 0                      NaN           NaN  ...                   0.000
# 1                      NaN           NaN  ...                   0.000
# 2                      NaN           NaN  ...                   0.000
# 3                      NaN           NaN  ...                   0.000
# 4                      NaN           NaN  ...                   0.000
#
#    odometry_wheelSpeed_rr  status_doorIsOpen  status_gridIsAvailable  \
# 0                   0.000              1.000                   0.000
# 1                   0.000              1.000                   0.000
# 2                   0.000              1.000                   0.000
# 3                   0.000              1.000                   0.000
# 4                   0.000              1.000                   0.000
#
#    status_haltBrakeIsActive  status_parkBrakeIsActive  temperature_ambient  \
# 0                     1.000                     0.000              292.150
# 1                     1.000                     0.000              292.150
# 2                     1.000                     0.000              292.150
# 3                     1.000                     0.000              292.150
# 4                     1.000                     0.000              292.150
#
#    traction_brakePressure  traction_tractionForce  \
# 0              856666.700                   0.000
# 1              860000.000                   0.000
# 2              861947.100                   0.000
# 3              865000.000                   0.000
# 4              870000.000                   0.000
#
#                                  Bus_identifier
# 0  B183_2020-11-13_14-52-45_2020-11-13_19-13-45
# 1  B183_2020-11-13_14-52-45_2020-11-13_19-13-45
# 2  B183_2020-11-13_14-52-45_2020-11-13_19-13-45
# 3  B183_2020-11-13_14-52-45_2020-11-13_19-13-45
# 4  B183_2020-11-13_14-52-45_2020-11-13_19-13-45
#
# [5 rows x 27 columns]

# %%
print(f"min: {dataframes['B183_2021-10-19_03-07-27_2021-10-19_21-38-02']['temperature_ambient'].min()}")
print(f"max: {dataframes['B183_2021-10-19_03-07-27_2021-10-19_21-38-02']['temperature_ambient'].max()}")
print(f"mean: {dataframes['B183_2021-10-19_03-07-27_2021-10-19_21-38-02']['temperature_ambient'].mean()}")
# Out:
# min: 281.15
# max: 292.15
# mean: 286.97774894201336

# %%
metadata[metadata['name'] == 'B183_2021-10-19_03-07-27_2021-10-19_21-38-02']
# Out:
#                                              name  busNumber  \
# 497  B183_2021-10-19_03-07-27_2021-10-19_21-38-02        183
#
#             startTime_iso  startTime_unix           endTime_iso  endTime_unix  \
# 497  2021-10-19T03:07:27Z      1634612847  2021-10-19T21:38:02Z    1634679482
#
#      drivenDistance busRoute  energyConsumption  itcs_numberOfPassengers_mean  \
# 497      289868.300       33     1616199000.000                        15.302
#
#      itcs_numberOfPassengers_min  itcs_numberOfPassengers_max  \
# 497                            0                           43
#
#      status_gridIsAvailable_mean  temperature_ambient_mean  \
# 497                        0.934                   286.995
#
#      temperature_ambient_min  temperature_ambient_max
# 497                  281.150                  292.150

# %% [markdown]
# I can use directly metadata and consider `temperature_ambient_mean`.

# %%
metadata['startTime_iso'] = pd.to_datetime(metadata['startTime_iso'])

# %%
metadata.dtypes
# Out:
# name                                         object
# busNumber                                     int64
# startTime_iso                   datetime64[ns, UTC]
# startTime_unix                                int64
# endTime_iso                                  object
# endTime_unix                                  int64
# drivenDistance                              float64
# busRoute                                     object
# energyConsumption                           float64
# itcs_numberOfPassengers_mean                float64
# itcs_numberOfPassengers_min                   int64
# itcs_numberOfPassengers_max                   int64
# status_gridIsAvailable_mean                 float64
# temperature_ambient_mean                    float64
# temperature_ambient_min                     float64
# temperature_ambient_max                     float64
# dtype: object

# %%
metadata.head()
# Out:
#                                            name  busNumber  \
# 0  B183_2019-04-30_03-18-56_2019-04-30_08-44-20        183
# 1  B183_2019-04-30_13-22-07_2019-04-30_17-54-02        183
# 2  B183_2019-05-01_05-58-51_2019-05-01_22-32-30        183
# 3  B183_2019-05-03_02-50-21_2019-05-03_05-53-20        183
# 4  B183_2019-05-03_15-41-57_2019-05-03_23-06-24        183
#
#               startTime_iso  startTime_unix           endTime_iso  \
# 0 2019-04-30 03:18:56+00:00      1556594336  2019-04-30T08:44:20Z
# 1 2019-04-30 13:22:07+00:00      1556630527  2019-04-30T17:54:02Z
# 2 2019-05-01 05:58:51+00:00      1556690331  2019-05-01T22:32:30Z
# 3 2019-05-03 02:50:21+00:00      1556851821  2019-05-03T05:53:20Z
# 4 2019-05-03 15:41:57+00:00      1556898117  2019-05-03T23:06:24Z
#
#    endTime_unix  drivenDistance busRoute  energyConsumption  \
# 0    1556613860       77213.870      NaN      478585200.000
# 1    1556646842       59029.600       31      402258500.000
# 2    1556749950      240900.400       33     1445733000.000
# 3    1556862800       42565.480      NaN      281986700.000
# 4    1556924784      125277.200       72      620725800.000
#
#    itcs_numberOfPassengers_mean  itcs_numberOfPassengers_min  \
# 0                         5.539                            0
# 1                        33.115                            4
# 2                        19.689                            0
# 3                         1.685                            0
# 4                        23.754                            1
#
#    itcs_numberOfPassengers_max  status_gridIsAvailable_mean  \
# 0                           20                        0.741
# 1                           74                        0.855
# 2                           55                        0.778
# 3                            8                        0.767
# 4                           67                        0.907
#
#    temperature_ambient_mean  temperature_ambient_min  temperature_ambient_max
# 0                   282.378                  281.150                  293.150
# 1                   287.544                  285.150                  293.150
# 2                   288.749                  280.150                  294.150
# 3                   282.413                  281.150                  292.150
# 4                   284.733                  282.150                  287.150

# %%
metadata.groupby(metadata['startTime_iso'].dt.month)['temperature_ambient_mean'].mean()
# Out:
# startTime_iso
# 1    278.958
# 2    280.530
# 3    283.319
# 4    286.608
# 5    290.052
# 6    296.143
# 7    297.377
# 8    295.848
# 9    292.362
# 10   287.714
# 11   281.884
# 12   279.382
# Name: temperature_ambient_mean, dtype: float64

# %% [markdown]
# ## 14. For each **bus** compute the total time when the halt brake is active and the total time when the park brake is active. Compute also the ratio between those two times.

# %% [markdown]
# "total time": sum of all the individual durations when the halt brake or park brake is active across all occurrences.

# %%
all_df = pd.read_csv(config['path_ZTbus_alldf'])
all_df.head()
# Out:
#                time_iso   time_unix  electric_powerDemand  gnss_altitude  \
# 0  2020-11-13T14:52:45Z  1605279165              9346.241            NaN
# 1  2020-11-13T14:52:46Z  1605279166              9819.954            NaN
# 2  2020-11-13T14:52:47Z  1605279167              9023.815            NaN
# 3  2020-11-13T14:52:48Z  1605279168              9187.615            NaN
# 4  2020-11-13T14:52:49Z  1605279169              9960.241        429.200
#
#    gnss_course  gnss_latitude  gnss_longitude itcs_busRoute  \
# 0          NaN            NaN             NaN             -
# 1          NaN            NaN             NaN             -
# 2          NaN            NaN             NaN             -
# 3          NaN            NaN             NaN             -
# 4        1.560          0.827           0.148             -
#
#    itcs_numberOfPassengers itcs_stopName  ...  odometry_wheelSpeed_rl  \
# 0                      NaN           NaN  ...                   0.000
# 1                      NaN           NaN  ...                   0.000
# 2                      NaN           NaN  ...                   0.000
# 3                      NaN           NaN  ...                   0.000
# 4                      NaN           NaN  ...                   0.000
#
#    odometry_wheelSpeed_rr  status_doorIsOpen  status_gridIsAvailable  \
# 0                   0.000              1.000                   0.000
# 1                   0.000              1.000                   0.000
# 2                   0.000              1.000                   0.000
# 3                   0.000              1.000                   0.000
# 4                   0.000              1.000                   0.000
#
#    status_haltBrakeIsActive  status_parkBrakeIsActive  temperature_ambient  \
# 0                     1.000                     0.000              292.150
# 1                     1.000                     0.000              292.150
# 2                     1.000                     0.000              292.150
# 3                     1.000                     0.000              292.150
# 4                     1.000                     0.000              292.150
#
#    traction_brakePressure  traction_tractionForce  \
# 0              856666.700                   0.000
# 1              860000.000                   0.000
# 2              861947.100                   0.000
# 3              865000.000                   0.000
# 4              870000.000                   0.000
#
#                                  Bus_identifier
# 0  B183_2020-11-13_14-52-45_2020-11-13_19-13-45
# 1  B183_2020-11-13_14-52-45_2020-11-13_19-13-45
# 2  B183_2020-11-13_14-52-45_2020-11-13_19-13-45
# 3  B183_2020-11-13_14-52-45_2020-11-13_19-13-45
# 4  B183_2020-11-13_14-52-45_2020-11-13_19-13-45
#
# [5 rows x 27 columns]

# %%
all_df.shape
# Out:
# (48674462, 27)

# %%
all_df.columns
# Out:
# Index(['time_iso', 'time_unix', 'electric_powerDemand', 'gnss_altitude',
#        'gnss_course', 'gnss_latitude', 'gnss_longitude', 'itcs_busRoute',
#        'itcs_numberOfPassengers', 'itcs_stopName',
#        'odometry_articulationAngle', 'odometry_steeringAngle',
#        'odometry_vehicleSpeed', 'odometry_wheelSpeed_fl',
#        'odometry_wheelSpeed_fr', 'odometry_wheelSpeed_ml',
#        'odometry_wheelSpeed_mr', 'odometry_wheelSpeed_rl',
#        'odometry_wheelSpeed_rr', 'status_doorIsOpen', 'status_gridIsAvailable',
#        'status_haltBrakeIsActive', 'status_parkBrakeIsActive',
#        'temperature_ambient', 'traction_brakePressure',
#        'traction_tractionForce', 'Bus_identifier'],
#       dtype='object')

# %%
all_df['status_haltBrakeIsActive'].unique(), all_df['status_parkBrakeIsActive'].unique()
# status_haltBrakeIsActive active when == 1
# status_parkBrakeIsActive active when == 1
# Out:
# (array([ 1.,  0., nan]), array([ 0.,  1., nan]))

# %%
all_df['Bus_number'] = all_df['Bus_identifier'].str.extract(r'B(\d+)')
all_df[['Bus_number', 'Bus_identifier']].head()
# Out:
#   Bus_number                                Bus_identifier
# 0        183  B183_2020-11-13_14-52-45_2020-11-13_19-13-45
# 1        183  B183_2020-11-13_14-52-45_2020-11-13_19-13-45
# 2        183  B183_2020-11-13_14-52-45_2020-11-13_19-13-45
# 3        183  B183_2020-11-13_14-52-45_2020-11-13_19-13-45
# 4        183  B183_2020-11-13_14-52-45_2020-11-13_19-13-45

# %%
halt_brake_active = all_df[all_df['status_haltBrakeIsActive'] == 1][['status_haltBrakeIsActive', 'Bus_number', 'time_unix']]
total_halt_brake_time = halt_brake_active.groupby('Bus_number', as_index=False)['time_unix'].sum()
total_halt_brake_time.rename(columns={'time_unix': 'Total_time_haltBrakeIsActive'}, inplace=True)
total_halt_brake_time
# Out:
#   Bus_number  Total_time_haltBrakeIsActive
# 0        183             12798119216668360
# 1        208              9772182191149324

# %%
park_brake_active = all_df[all_df['status_parkBrakeIsActive'] == 1][['status_parkBrakeIsActive', 'Bus_number', 'time_unix']]
total_park_brake_time = park_brake_active.groupby('Bus_number', as_index=False)['time_unix'].sum()
total_park_brake_time.rename(columns={'time_unix': 'Total_time_parkBrakeIsActive'}, inplace=True)
total_park_brake_time
# Out:
#   Bus_number  Total_time_parkBrakeIsActive
# 0        183              5145602662745631
# 1        208              3006515883060711

# %%
total_halt_park_brake_time = pd.merge(total_halt_brake_time, total_park_brake_time, on='Bus_number')
total_halt_park_brake_time
# Out:
#   Bus_number  Total_time_haltBrakeIsActive  Total_time_parkBrakeIsActive
# 0        183             12798119216668360              5145602662745631
# 1        208              9772182191149324              3006515883060711

# %%
total_halt_park_brake_time['Ratio'] = total_halt_park_brake_time['Total_time_haltBrakeIsActive'] / total_halt_park_brake_time['Total_time_parkBrakeIsActive']
total_halt_park_brake_time
# Out:
#   Bus_number  Total_time_haltBrakeIsActive  Total_time_parkBrakeIsActive  \
# 0        183             12798119216668360              5145602662745631
# 1        208              9772182191149324              3006515883060711
#
#    Ratio
# 0  2.487
# 1  3.250

# %% [markdown]
# ## 15. For each pair of stops that are consecutive in all trips, compute the average speed achieved when going from the first to the second stop.

# %% [markdown]
# To calculate the average speed between consecutive stops across I follow the following steps:
#
# * Iterate through each DataFrame in the `dataframes`.
# * For each DataFrame, sort the rows based on the `time_iso` column to ensure that the data is ordered by time.
# * Iterate through the rows of each DataFrame and calculate the speed between consecutive stops.
# * Keep track of the total speed and the count of observations for each pair of consecutive stops.
# * After processing all DataFrames, calculate the average speed for each pair of stops.

# %%
dataframes['B183_2019-05-03_02-50-21_2019-05-03_05-53-20'].columns
# Out:
# Index(['time_iso', 'time_unix', 'electric_powerDemand', 'gnss_altitude',
#        'gnss_course', 'gnss_latitude', 'gnss_longitude', 'itcs_busRoute',
#        'itcs_numberOfPassengers', 'itcs_stopName',
#        'odometry_articulationAngle', 'odometry_steeringAngle',
#        'odometry_vehicleSpeed', 'odometry_wheelSpeed_fl',
#        'odometry_wheelSpeed_fr', 'odometry_wheelSpeed_ml',
#        'odometry_wheelSpeed_mr', 'odometry_wheelSpeed_rl',
#        'odometry_wheelSpeed_rr', 'status_doorIsOpen', 'status_gridIsAvailable',
#        'status_haltBrakeIsActive', 'status_parkBrakeIsActive',
#        'temperature_ambient', 'traction_brakePressure',
#        'traction_tractionForce'],
#       dtype='object')

# %%
dataframes['B183_2019-05-03_02-50-21_2019-05-03_05-53-20']['itcs_stopName'].unique()
# Out:
# array(['-', 'Zürich, Bahnhof Tiefenbrunnen', 'Zürich, Wildbachstrasse',
#        'Zürich, Fröhlichstrasse', 'Zürich, Höschgasse',
#        'Zürich, Botanischer Garten', 'Zürich, Hegibachplatz',
#        'Zürich, Freiestrasse', 'Zürich, Klusplatz',
#        'Zürich, Hölderlinsteig', 'Zürich, Klosbach', 'Zürich, Hofstrasse',
#        'Zürich, Kirche Fluntern', 'Zürich, Hinterbergstrasse',
#        'Zürich, Spyriplatz', 'Zürich, Bethanien', 'Zürich, Toblerplatz'],
#       dtype=object)

# %%
# Dictionary to store total speed and count for each pair of consecutive stops
speed_data = {}

# Iterate through each trip DataFrame
for trip_name, df in dataframes.items():
    # Sort the DataFrame by time_iso
    df = df.sort_values(by='time_iso')
    df['itcs_stopName'].replace('-', pd.NA, inplace=True)
    df.dropna(subset=['itcs_stopName'], inplace=True)

    # Iterate through consecutive pairs of stops
    for i in range(1, len(df)):
        # Get information about the current and previous stops
        current_stop = df.iloc[i]
        previous_stop = df.iloc[i - 1]
        
        if current_stop['itcs_stopName'] != previous_stop['itcs_stopName']: 
            
            # Use 'odometry_vehicleSpeed' as an approximation of the speed achieved between stops
            speed = (current_stop['odometry_vehicleSpeed'] + previous_stop['odometry_vehicleSpeed'])/2 

            # Update total speed and count in the speed_data dictionary
            stop_pair = (previous_stop['itcs_stopName'], current_stop['itcs_stopName'])
            if stop_pair not in speed_data:
                speed_data[stop_pair] = {'total_speed': 0, 'count': 0}
            speed_data[stop_pair]['total_speed'] += speed
            speed_data[stop_pair]['count'] += 1
        
        # else:
        # skip row because previous_stop does not have a reliable result

# Calculate average speed for each pair of stops
average_speeds = {}
for stop_pair, data in speed_data.items():
    average_speeds[stop_pair] = data['total_speed'] / data['count']

# %%
# Display or use the average_speeds dictionary as needed
average_speeds
# Out:
# {('Zürich, Herdernstrasse', 'Zürich, SBB-Werkstätte'): 1.9758231539436941,
#  ('Zürich, SBB-Werkstätte', 'Zürich, Letzipark'): 3.314002531273578,
#  ('Zürich, Letzipark', 'Zürich, Letzibach'): 3.5891002301153225,
#  ('Zürich, Letzibach', 'Zürich, Bahnhof Altstetten'): 1.4497333521620683,
#  ('Zürich, Bahnhof Altstetten', 'Zürich, Bristenstrasse'): 0.6760360256506872,
#  ('Zürich, Bristenstrasse', 'Zürich, Baslerstrasse'): 1.287784802879027,
#  ('Zürich, Baslerstrasse', 'Zürich, Letzipark West'): 1.2173241926076126,
#  ('Zürich, Letzipark West', 'Zürich, Kappeli'): 0.6834191179832109,
#  ('Zürich, Kappeli', 'Zürich, Flurstrasse'): 0.6282382666429805,
#  ('Zürich, Flurstrasse', 'Zürich, Albisrank'): 0.5342487272443125,
#  ('Zürich, Albisrank', 'Zürich, Hubertus'): 0.5906666780807042,
#  ('Zürich, Hubertus', 'Zürich, Altes Krematorium'): 0.7964138220530517,
#  ('Zürich, Altes Krematorium', 'Zürich, Albisriederplatz'): 0.6839227105868482,
#  ('Zürich, Albisriederplatz', 'Zürich, Hardplatz'): 0.42723087091378176,
#  ('Zürich, Hardplatz', 'Zürich, Bahnhof Hardbrücke'): 0.5146907400573569,
#  ('Zürich, Bahnhof Hardbrücke', 'Zürich, Schiffbau'): 0.7033396345096475,
#  ('Zürich, Schiffbau', 'Zürich, Escher-Wyss-Platz'): 0.7204174397144048,
#  ('Zürich, Escher-Wyss-Platz',
#   'Zürich, Rosengartenstrasse'): 0.5455260728689411,
#  ('Zürich, Rosengartenstrasse', 'Zürich, Bucheggplatz'): 0.4849494460365183,
#  ('Zürich, Bucheggplatz', 'Zürich, Milchbuck'): 0.45842999886373276,
#  ('Zürich, Milchbuck', 'Zürich, Bucheggplatz'): 0.48955062138397043,
#  ('Zürich, Bucheggplatz', 'Zürich, Rosengartenstrasse'): 0.5338479135269844,
#  ('Zürich, Rosengartenstrasse',
#   'Zürich, Escher-Wyss-Platz'): 0.5871850374909564,
#  ('Zürich, Escher-Wyss-Platz', 'Zürich, Schiffbau'): 0.7555104056841659,
#  ('Zürich, Schiffbau', 'Zürich, Bahnhof Hardbrücke'): 0.7467726659567839,
#  ('Zürich, Bahnhof Hardbrücke', 'Zürich, Hardplatz'): 0.5460367364725138,
#  ('Zürich, Hardplatz', 'Zürich, Albisriederplatz'): 0.5041254408326856,
#  ('Zürich, Albisriederplatz', 'Zürich, Altes Krematorium'): 0.791745699983906,
#  ('Zürich, Altes Krematorium', 'Zürich, Hubertus'): 0.8158643356664503,
#  ('Zürich, Hubertus', 'Zürich, Albisrank'): 0.6723786209638554,
#  ('Zürich, Albisrank', 'Zürich, Flurstrasse'): 0.679368284964321,
#  ('Zürich, Flurstrasse', 'Zürich, Kappeli'): 0.6759503644389471,
#  ('Zürich, Kappeli', 'Zürich, Letzipark West'): 0.8724998233616958,
#  ('Zürich, Letzipark West', 'Zürich, Letzibach'): 1.4983250007968005,
#  ('Zürich, Rosengartenstrasse', 'Zürich, Lehenstrasse'): 0.6373887818333333,
#  ('Zürich, Lehenstrasse', 'Zürich, Rebbergsteig'): 1.9388880325397402,
#  ('Zürich, Rebbergsteig', 'Zürich, Kempfhofsteig'): 3.1083011488900385,
#  ('Zürich, Kempfhofsteig', 'Zürich, Schwert'): 2.0399582611271305,
#  ('Zürich, Schwert', 'Zürich, Meierhofplatz'): 0.5453562283543847,
#  ('Zürich, Meierhofplatz', 'Zürich, Wieslergasse'): 0.6906859477460854,
#  ('Zürich, Wieslergasse', 'Zürich, Singlistrasse'): 2.134490943989615,
#  ('Zürich, Singlistrasse', 'Zürich, Segantinistrasse'): 2.465780991631939,
#  ('Zürich, Segantinistrasse', 'Zürich, Giblenstrasse'): 2.003384105374483,
#  ('Zürich, Giblenstrasse', 'Zürich, Heizenholz'): 1.8199256611245775,
#  ('Zürich, Heizenholz', 'Zürich, Geeringstrasse'): 0.9222716530828884,
#  ('Zürich, Geeringstrasse', 'Zürich, Rütihof'): 0.34258886250193604,
#  ('Zürich, Rütihof', 'Zürich, Geeringstrasse'): 0.4294061582557214,
#  ('Zürich, Geeringstrasse', 'Zürich, Heizenholz'): 1.2015059838731763,
#  ('Zürich, Heizenholz', 'Zürich, Giblenstrasse'): 2.3549091162179367,
#  ('Zürich, Giblenstrasse', 'Zürich, Segantinistrasse'): 2.5654408303301937,
#  ('Zürich, Segantinistrasse', 'Zürich, Singlistrasse'): 2.7114523737398724,
#  ('Zürich, Singlistrasse', 'Zürich, Wieslergasse'): 2.235112539510817,
#  ('Zürich, Wieslergasse', 'Zürich, Meierhofplatz'): 0.7819915788622074,
#  ('Zürich, Meierhofplatz', 'Zürich, Schwert'): 0.5204924244685939,
#  ('Zürich, Schwert', 'Zürich, Kempfhofsteig'): 2.2352504273085607,
#  ('Zürich, Kempfhofsteig', 'Zürich, Rebbergsteig'): 3.577137459730481,
#  ('Zürich, Rebbergsteig', 'Zürich, Lehenstrasse'): 2.410655513424891,
#  ('Zürich, Lehenstrasse', 'Zürich, Rosengartenstrasse'): 0.9753425217797659,
#  ('Zürich, Rosengartenstrasse',
#   'Zürich, Bahnhof Wipkingen'): 0.3952726659492637,
#  ('Zürich, Bahnhof Wipkingen', 'Zürich, Lettenstrasse'): 0.7479006732137803,
#  ('Zürich, Lettenstrasse', 'Zürich, Okenstrasse'): 1.2076269574310519,
#  ('Zürich, Okenstrasse', 'Zürich, Stampfenbachplatz'): 0.7784458407026079,
#  ('Zürich, Stampfenbachplatz', 'Zürich, Central'): 0.3133161668507283,
#  ('Zürich, Central', 'Zürich, Bahnhofquai/HB'): 0.29312888633902157,
#  ('Zürich, Bahnhofquai/HB', 'Zürich, Stampfenbachplatz'): 0.3347810336045063,
#  ('Zürich, Stampfenbachplatz', 'Zürich, Nordstrasse'): 0.4020317159037598,
#  ('Zürich, Nordstrasse', 'Zürich, Lettenstrasse'): 0.7410422856293207,
#  ('Zürich, Lettenstrasse', 'Zürich, Bahnhof Wipkingen'): 0.6541312896666704,
#  ('Zürich, Bahnhof Wipkingen',
#   'Zürich, Rosengartenstrasse'): 0.34269402535823285,
#  ('Zürich, Hubertus', 'Zürich, Sackzelg'): 0.5287490698018965,
#  ('Zürich, Sackzelg', 'Zürich, Schulhaus Altweg'): 0.9212682619515852,
#  ('Zürich, Schulhaus Altweg', 'Zürich, In der Ey'): 0.8701215412597235,
#  ('Zürich, In der Ey', 'Zürich, Triemli'): 0.4664617189055409,
#  ('Zürich, Triemli', 'Zürich, In der Ey'): 0.5047381525786909,
#  ('Zürich, In der Ey', 'Zürich, Schulhaus Altweg'): 0.815092308803217,
#  ('Zürich, Schulhaus Altweg', 'Zürich, Sackzelg'): 0.7346526255778711,
#  ('Zürich, Sackzelg', 'Zürich, Hubertus'): 0.42139282532442796,
#  ('Zürich, Bahnhof Wipkingen', 'Zürich, Nürenbergstrasse'): 1.152895702137644,
#  ('Zürich, Nürenbergstrasse', 'Zürich, Rotbuchstrasse'): 1.15439928964697,
#  ('Zürich, Rotbuchstrasse', 'Zürich, Schaffhauserplatz'): 0.3735903588286845,
#  ('Zürich, Schaffhauserplatz',
#   'Zürich, Scheuchzerstrasse'): 0.6237728321667689,
#  ('Zürich, Scheuchzerstrasse',
#   'Zürich, Seilbahn Rigiblick'): 0.6193588090583032,
#  ('Zürich, Seilbahn Rigiblick',
#   'Zürich, Vogelsangstrasse'): 0.5138542944430476,
#  ('Zürich, Vogelsangstrasse', 'Zürich, Spyriplatz'): 0.5923732142189054,
#  ('Zürich, Spyriplatz', 'Zürich, Bethanien'): 0.8355774116699454,
#  ('Zürich, Bethanien', 'Zürich, Toblerplatz'): 0.8092181203264993,
#  ('Zürich, Toblerplatz', 'Zürich, Kirche Fluntern'): 0.39250097218509616,
#  ('Zürich, Kirche Fluntern', 'Zürich, Hofstrasse'): 0.8335599921383243,
#  ('Zürich, Hofstrasse', 'Zürich, Klosbach'): 1.4269123501836098,
#  ('Zürich, Klosbach', 'Zürich, Hölderlinsteig'): 2.1596740089815407,
#  ('Zürich, Hölderlinsteig', 'Zürich, Klusplatz'): 1.5857245044343355,
#  ('Zürich, Klusplatz', 'Zürich, Freiestrasse'): 1.2690798856644392,
#  ('Zürich, Freiestrasse', 'Zürich, Hegibachplatz'): 1.2890478324612902,
#  ('Zürich, Hegibachplatz', 'Zürich, Botanischer Garten'): 0.5990228767276993,
#  ('Zürich, Botanischer Garten', 'Zürich, Höschgasse'): 0.5631348920878606,
#  ('Zürich, Höschgasse', 'Zürich, Fröhlichstrasse'): 1.322028741643663,
#  ('Zürich, Fröhlichstrasse', 'Zürich, Wildbachstrasse'): 2.7906854360522853,
#  ('Zürich, Wildbachstrasse',
#   'Zürich, Bahnhof Tiefenbrunnen'): 1.8372042383283178,
#  ('Zürich, Bahnhof Tiefenbrunnen',
#   'Zürich, Wildbachstrasse'): 0.902245869055799,
#  ('Zürich, Wildbachstrasse', 'Zürich, Fröhlichstrasse'): 1.1000789955552643,
#  ('Zürich, Fröhlichstrasse', 'Zürich, Höschgasse'): 0.6069546330117856,
#  ('Zürich, Höschgasse', 'Zürich, Botanischer Garten'): 0.6751754942789392,
#  ('Zürich, Botanischer Garten', 'Zürich, Hegibachplatz'): 0.6236356137940681,
#  ('Zürich, Hegibachplatz', 'Zürich, Freiestrasse'): 0.72854140642459,
#  ('Zürich, Freiestrasse', 'Zürich, Klusplatz'): 0.7263004304222067,
#  ('Zürich, Klusplatz', 'Zürich, Hölderlinsteig'): 1.4578053703365357,
#  ('Zürich, Hölderlinsteig', 'Zürich, Klosbach'): 1.978701486407882,
#  ('Zürich, Klosbach', 'Zürich, Hofstrasse'): 1.460766749773631,
#  ('Zürich, Hofstrasse', 'Zürich, Kirche Fluntern'): 0.9734289752210735,
#  ('Zürich, Kirche Fluntern', 'Zürich, Hinterbergstrasse'): 0.8027122050243352,
#  ('Zürich, Hinterbergstrasse', 'Zürich, Spyriplatz'): 0.8617977642335243,
#  ('Zürich, Spyriplatz', 'Zürich, Vogelsangstrasse'): 0.9622042238668674,
#  ('Zürich, Vogelsangstrasse',
#   'Zürich, Seilbahn Rigiblick'): 0.8661018166594106,
#  ('Zürich, Seilbahn Rigiblick',
#   'Zürich, Scheuchzerstrasse'): 0.7107163028087888,
#  ('Zürich, Scheuchzerstrasse',
#   'Zürich, Schaffhauserplatz'): 0.7225159890847638,
#  ('Zürich, Schaffhauserplatz', 'Zürich, Rotbuchstrasse'): 0.5201675295510524,
#  ('Zürich, Rotbuchstrasse', 'Zürich, Nürenbergstrasse'): 1.2577904045319817,
#  ('Zürich, Nürenbergstrasse', 'Zürich, Bahnhof Wipkingen'): 1.1073931006547415,
#  ('Zürich, Albisriederplatz', 'Zürich, Friedhof Sihlfeld'): 0.503155440926073,
#  ('Zürich, Friedhof Sihlfeld', 'Zürich, Bertastrasse'): 0.7531780250496004,
#  ('Zürich, Bertastrasse', 'Zürich, Zwinglihaus'): 0.6199369898122916,
#  ('Zürich, Zwinglihaus', 'Zürich, Schmiede Wiedikon'): 0.386287764267021,
#  ('Zürich, Schmiede Wiedikon', 'Zürich, Hertersteg'): 0.6168213522485838,
#  ('Zürich, Hertersteg', 'Zürich, Manesseplatz'): 0.6484300913454027,
#  ('Zürich, Manesseplatz', 'Zürich, Sihlcity Nord'): 0.4392573603089156,
#  ('Zürich, Sihlcity Nord', 'Zürich, Waffenplatzstrasse'): 0.40569585528578567,
#  ('Zürich, Waffenplatzstrasse', 'Zürich, Hügelstrasse'): 1.0547278201525094,
#  ('Zürich, Hügelstrasse',
#   'Zürich, Brunau/Mutschellenstr.'): 1.3639536073776715,
#  ('Zürich, Brunau/Mutschellenstr.', 'Zürich, Thujastrasse'): 1.159887429305195,
#  ('Zürich, Thujastrasse', 'Zürich, Jugendherberge'): 1.2865471398966497,
#  ('Zürich, Jugendherberge', 'Zürich, Besenrainstrasse'): 2.11508106787346,
#  ('Zürich, Besenrainstrasse', 'Zürich, Morgental'): 1.8846662357367507,
#  ('Zürich, Morgental', 'Zürich, Jugendherberge'): 1.0253246058471468,
#  ('Zürich, Jugendherberge', 'Zürich, Thujastrasse'): 1.188279871374198,
#  ('Zürich, Thujastrasse',
#   'Zürich, Brunau/Mutschellenstr.'): 1.0450727422480897,
#  ('Zürich, Brunau/Mutschellenstr.',
#   'Zürich, Hügelstrasse'): 1.1469129179013913,
#  ('Zürich, Hügelstrasse',
#   'Zürich, Waffenplatz-/Bederstr.'): 0.8547378049052804,
#  ('Zürich, Waffenplatz-/Bederstr.',
#   'Zürich, Waffenplatzstrasse'): 0.8028000796624434,
#  ('Zürich, Waffenplatzstrasse', 'Zürich, Sihlcity Nord'): 0.848964254974596,
#  ('Zürich, Sihlcity Nord', 'Zürich, Manesseplatz'): 0.47285490335052727,
#  ('Zürich, Manesseplatz', 'Zürich, Hertersteg'): 0.9096744229504983,
#  ('Zürich, Hertersteg', 'Zürich, Schmiede Wiedikon'): 0.8099726444717582,
#  ('Zürich, Schmiede Wiedikon', 'Zürich, Zwinglihaus'): 0.38609107067949033,
#  ('Zürich, Zwinglihaus', 'Zürich, Bertastrasse'): 0.5885193065419445,
#  ('Zürich, Bertastrasse', 'Zürich, Friedhof Sihlfeld'): 1.5098376751293232,
#  ('Zürich, Friedhof Sihlfeld',
#   'Zürich, Altes Krematorium'): 1.7553949773404092,
#  ('Zürich, Letzibach', 'Zürich, Milchbuck'): 1.5992177411756763,
#  ('Zürich, Herdernstrasse', 'Zürich, Hardplatz'): 0.6441490873873855,
#  ('Zürich, Hardplatz', 'Zürich, Güterbahnhof'): 0.4992614824853208,
#  ('Zürich, Güterbahnhof', 'Zürich, Bäckeranlage'): 0.5265593317873857,
#  ('Zürich, Bäckeranlage', 'Zürich, Militär-/Langstrasse'): 0.3827335881519298,
#  ('Zürich, Militär-/Langstrasse', 'Zürich, Kanonengasse'): 0.4393138830052357,
#  ('Zürich, Kanonengasse', 'Zürich, Sihlpost / HB'): 0.5258792440992104,
#  ('Zürich, Sihlpost / HB', 'Zürich, Löwenplatz'): 0.7210832864623684,
#  ('Zürich, Löwenplatz', 'Zürich, Bahnhofplatz/HB'): 0.5123258790766485,
#  ('Zürich, Bahnhofplatz/HB', 'Zürich, Sihlquai/HB'): 0.2805581648910001,
#  ('Zürich, Sihlquai/HB', 'Zürich, Museum für Gestaltung'): 1.3694914354668335,
#  ('Zürich, Museum für Gestaltung', 'Zürich, Limmatplatz'): 1.3028855695758332,
#  ('Zürich, Limmatplatz', 'Zürich, Quellenstrasse'): 0.1966957453666667,
#  ('Zürich, Quellenstrasse', 'Zürich, Löwenbräu'): 1.7735526576166663,
#  ('Zürich, Löwenbräu', 'Zürich, Escher-Wyss-Platz'): 1.7750666758158333,
#  ('Zürich, Escher-Wyss-Platz', 'Zürich, Löwenbräu'): 4.3218263335,
#  ('Zürich, Löwenbräu', 'Zürich, Quellenstrasse'): 4.404188154670212,
#  ('Zürich, Quellenstrasse', 'Zürich, Limmatplatz'): 0.5560222002712767,
#  ('Zürich, Limmatplatz', 'Zürich, Museum für Gestaltung'): 1.1671042571927084,
#  ('Zürich, Museum für Gestaltung', 'Zürich, Sihlquai/HB'): 1.8790266808229161,
#  ('Zürich, Sihlquai/HB', 'Zürich, Bahnhofplatz/HB'): 0.8024224543536586,
#  ('Zürich, Bahnhofplatz/HB', 'Zürich, Löwenplatz'): 0.2627312218988151,
#  ('Zürich, Löwenplatz', 'Zürich, Sihlpost / HB'): 0.35981280206966815,
#  ('Zürich, Sihlpost / HB', 'Zürich, Kanonengasse'): 0.5164339602438388,
#  ('Zürich, Kanonengasse', 'Zürich, Militär-/Langstrasse'): 0.40830554671303315,
#  ('Zürich, Militär-/Langstrasse', 'Zürich, Bäckeranlage'): 0.5924443308271929,
#  ('Zürich, Bäckeranlage', 'Zürich, Güterbahnhof'): 0.5786043869870535,
#  ('Zürich, Güterbahnhof', 'Zürich, Hardplatz'): 0.3640932216566964,
#  ('Zürich, Hardplatz', 'Zürich, Herdernstrasse'): 0.4045634712932352,
#  ('Zürich, Bristenstrasse', 'Zürich, Lindenplatz'): 2.4239874983611114,
#  ('Zürich, Lindenplatz', 'Zürich, Rautistrasse'): 0.9986618177787037,
#  ('Zürich, Rautistrasse', 'Zürich, Schulhaus Buchlern'): 2.8300418962972214,
#  ('Zürich, Schulhaus Buchlern', 'Zürich, Rautihalde'): 2.9531505300277767,
#  ('Zürich, Rautihalde', 'Zürich, Salzweg'): 4.580163672148148,
#  ('Zürich, Salzweg', 'Zürich, Bahnhofplatz/HB'): 6.827426416666667,
#  ('Zürich, Salzweg', 'Zürich, Dunkelhölzli'): 3.6887917872777782,
#  ('Zürich, Dunkelhölzli', 'Zürich, Salzweg'): 4.9830486846046504,
#  ('Zürich, Salzweg', 'Zürich, Rautihalde'): 9.684912840069767,
#  ('Zürich, Rautihalde', 'Zürich, Schulhaus Buchlern'): 10.09952801383721,
#  ('Zürich, Schulhaus Buchlern', 'Zürich, Rautistrasse'): 7.958965621965113,
#  ('Zürich, Rautistrasse', 'Zürich, Lindenplatz'): 4.519378873325581,
#  ('Zürich, Lindenplatz', 'Zürich, Bristenstrasse'): 4.09821157672907,
#  ('Zürich, Bristenstrasse', 'Zürich, Bahnhof Altstetten'): 2.7741207637081398,
#  ('Zürich, Bahnhof Altstetten', 'Zürich, Letzibach'): 1.2398803009181962,
#  ('Zürich, Letzibach', 'Zürich, Letzipark'): 2.355134723371299,
#  ('Zürich, Letzipark', 'Zürich, SBB-Werkstätte'): 1.8952360343176586,
#  ('Zürich, SBB-Werkstätte', 'Zürich, Herdernstrasse'): 1.104083222160667,
#  ('Zürich, Geeringstrasse', 'Zürich, Bahnhofplatz/HB'): 0.7224503234166667,
#  ('Zürich, Wildbachstrasse', 'Zürich, Triemli'): 1.0764937376666668,
#  ('Zürich, Hegibachplatz', 'Zürich, Signaustrasse'): 1.2163694088309378,
#  ('Zürich, Signaustrasse', 'Zürich, Kreuzplatz'): 1.4837444565975004,
#  ('Zürich, Kreuzplatz', 'Zürich, Sprecherstrasse'): 2.158415667986563,
#  ('Zürich, Sprecherstrasse', 'Zürich, Kunsthaus'): 1.9002336439437495,
#  ('Zürich, Kunsthaus', 'Zürich, Neumarkt'): 0.29590792205156247,
#  ('Zürich, Neumarkt', 'Zürich, Central'): 0.25090930558125,
#  ('Zürich, Central', 'Zürich, Bahnhofplatz/HB'): 0.19938373496509432,
#  ('Zürich, Geeringstrasse', 'Zürich, Dunkelhölzli'): 0.6933768,
#  ('Zürich, Löwenplatz', 'Zürich, Rütihof'): 2.035319275,
#  ('Zürich, Sihlcity', 'Zürich, Saalsporthalle'): 2.897074270277027,
#  ('Zürich, Saalsporthalle', 'Zürich, Laubegg'): 5.8403077549189195,
#  ('Zürich, Laubegg', 'Zürich, Uetlihof'): 7.635028752837836,
#  ('Zürich, Uetlihof', 'Zürich, Strassenverkehrsamt'): 4.935245675221623,
#  ('Zürich, Strassenverkehrsamt', 'Zürich, Hegianwandweg'): 1.6937269517638784,
#  ('Zürich, Hegianwandweg', 'Zürich, Im Hagacker'): 2.8338979293047553,
#  ('Zürich, Im Hagacker', 'Zürich, Friesenbergstrasse'): 1.8611054147416353,
#  ('Zürich, Friesenbergstrasse', 'Zürich, Friesenberg'): 1.3818492163504006,
#  ('Zürich, Friesenberg', 'Zürich, Höfliweg'): 2.456625230731889,
#  ('Zürich, Höfliweg', 'Zürich, Goldbrunnenplatz'): 1.7173941329436062,
#  ('Zürich, Goldbrunnenplatz', 'Zürich, Zwinglihaus'): 0.5589197157029582,
#  ('Zürich, Zwinglihaus', 'Zürich,Kalkbreite/Bhf.Wiedikon'): 0.5393421567109432,
#  ('Zürich,Kalkbreite/Bhf.Wiedikon', 'Zürich, Kernstrasse'): 0.5785295778952826,
#  ('Zürich, Kernstrasse', 'Zürich, Helvetiaplatz'): 0.578983493311132,
#  ('Zürich, Helvetiaplatz', 'Zürich, Bäckeranlage'): 0.318546667,
#  ('Zürich, Militär-/Langstrasse',
#   'Zürich, Röntgenstrasse'): 0.35723747748590223,
#  ('Zürich, Röntgenstrasse', 'Zürich, Limmatplatz'): 0.3882828190883462,
#  ('Zürich, Limmatplatz', 'Zürich, Nordstrasse'): 0.546529480842857,
#  ('Zürich, Nordstrasse', 'Zürich, Rotbuchstrasse'): 0.5908268933635341,
#  ('Zürich, Rotbuchstrasse', 'Zürich, Lägernstrasse'): 0.9889300104266923,
#  ('Zürich, Lägernstrasse', 'Zürich, Bucheggplatz'): 0.9222041100110902,
#  ('Zürich, Bucheggplatz', 'Zürich, Radiostudio'): 0.42049509084891695,
#  ('Zürich, Radiostudio', 'Zürich, Birchdörfli'): 0.9611322489819495,
#  ('Zürich, Birchdörfli', 'Zürich, Neuaffoltern'): 1.0144510798259927,
#  ('Zürich, Neuaffoltern', 'Zürich, Glaubtenstrasse'): 0.5046612303691335,
#  ('Zürich, Glaubtenstrasse', 'Zürich, Einfangstrasse'): 0.7210930605266304,
#  ('Zürich, Einfangstrasse', 'Zürich, Zehntenhausplatz'): 0.7627703926915399,
#  ('Zürich, Zehntenhausplatz', 'Zürich, Hungerbergstrasse'): 0.705948665758291,
#  ('Zürich, Helvetiaplatz', 'Zürich, Militär-/Langstrasse'): 0.413968632785083,
#  ('Zürich, Hungerbergstrasse', 'Zürich, Holzerhurd'): 0.6274272333506757,
#  ('Zürich, Holzerhurd', 'Zürich, Hungerbergstrasse'): 0.8708788258720092,
#  ('Zürich, Hungerbergstrasse', 'Zürich, Zehntenhausplatz'): 0.9486191487433765,
#  ('Zürich, Zehntenhausplatz', 'Zürich, Einfangstrasse'): 1.545111121378054,
#  ('Zürich, Einfangstrasse', 'Zürich, Glaubtenstrasse'): 1.7590849726409732,
#  ('Zürich, Glaubtenstrasse', 'Zürich, Neuaffoltern'): 1.5310094959953622,
#  ('Zürich, Neuaffoltern', 'Zürich, Birchdörfli'): 2.704145306496182,
#  ('Zürich, Birchdörfli', 'Zürich, Radiostudio'): 2.137786659871567,
#  ('Zürich, Radiostudio', 'Zürich, Bucheggplatz'): 0.6937951966089694,
#  ('Zürich, Bucheggplatz', 'Zürich, Lägernstrasse'): 1.048918902592941,
#  ('Zürich, Lägernstrasse', 'Zürich, Rotbuchstrasse'): 1.299049785109373,
#  ('Zürich, Rotbuchstrasse', 'Zürich, Nordstrasse'): 1.3087117798342744,
#  ('Zürich, Nordstrasse', 'Zürich, Limmatplatz'): 1.0719671839896072,
#  ('Zürich, Limmatplatz', 'Zürich, Röntgenstrasse'): 0.48435391895155644,
#  ('Zürich, Röntgenstrasse',
#   'Zürich, Militär-/Langstrasse'): 0.47646388918151744,
#  ('Zürich, Militär-/Langstrasse',
#   'Zürich, Helvetiaplatz'): 0.41062221329062454,
#  ('Zürich, Helvetiaplatz', 'Zürich, Kernstrasse'): 0.42707962080370354,
#  ('Zürich, Kernstrasse',
#   'Zürich,Kalkbreite/Bhf.Wiedikon'): 0.40755115215500015,
#  ('Zürich,Kalkbreite/Bhf.Wiedikon', 'Zürich, Zwinglihaus'): 0.514093241617963,
#  ('Zürich, Zwinglihaus', 'Zürich, Goldbrunnenplatz'): 0.4767851651825926,
#  ('Zürich, Goldbrunnenplatz', 'Zürich, Höfliweg'): 0.7746108189168516,
#  ('Zürich, Höfliweg', 'Zürich, Friesenberg'): 1.011475372681852,
#  ('Zürich, Friesenberg', 'Zürich, Friesenbergstrasse'): 0.6429100558146296,
#  ('Zürich, Friesenbergstrasse', 'Zürich, Im Hagacker'): 1.1782877857183338,
#  ('Zürich, Im Hagacker', 'Zürich, Hegianwandweg'): 1.6260671585414816,
#  ('Zürich, Hegianwandweg', 'Zürich, Holzerhurd'): 0.74941433375,
#  ('Zürich, Hegianwandweg', 'Zürich, Strassenverkehrsamt'): 0.9712334422543232,
#  ('Zürich, Zehntenhausplatz', 'Zürich, Bahnhof Affoltern'): 0.5911365429487179,
#  ('Zürich, Bahnhof Affoltern', 'Zürich, Fronwald'): 2.361747119310256,
#  ('Zürich, Fronwald', 'Zürich, Unteraffoltern'): 4.055295282915385,
#  ('Zürich, Unteraffoltern', 'Zürich, Schwandenholz'): 4.327177641953846,
#  ('Zürich, Schwandenholz', 'Zürich, Waidhof'): 1.7969279792272728,
#  ('Zürich, Waidhof', 'Zürich, Schwandenholz'): 3.222720326857143,
#  ('Zürich, Schwandenholz', 'Zürich, Unteraffoltern'): 5.944118451071428,
#  ('Zürich, Unteraffoltern', 'Zürich, Fronwald'): 5.804670200178571,
#  ('Zürich, Fronwald', 'Zürich, Bahnhof Affoltern'): 3.59374771675,
#  ('Zürich, Bahnhof Affoltern', 'Zürich, Zehntenhausplatz'): 0.7362479855535715,
#  ('Zürich, Bäckeranlage', 'Zürich, Helvetiaplatz'): 0.9870759068608975,
#  ('Zürich, Strassenverkehrsamt', 'Zürich, Uetlihof'): 4.034173467083333,
#  ('Zürich, Uetlihof', 'Zürich, Laubegg'): 5.2863179840769225,
#  ('Zürich, Laubegg', 'Zürich, Saalsporthalle'): 4.037981393858974,
#  ('Zürich, Saalsporthalle', 'Zürich, Sihlcity'): 2.4812712625862074,
#  ('Zürich, Hubertus', 'Zürich, Escher-Wyss-Platz'): 0.2810222,
#  ('Zürich, Bucheggplatz', 'Zürich, Bahnhof Altstetten'): 1.2542832674010567,
#  ('Zürich, Schmiede Wiedikon', 'Zürich, Manesseplatz'): 0.25158261316686914,
#  ('Zürich, Manesseplatz', 'Zürich, Schmiede Wiedikon'): 0.16438521262702446,
#  ('Zürich, Bahnhof Altstetten', 'Zürich, Seidelhof'): 1.045352485425357,
#  ('Zürich, Seidelhof', 'Zürich, Farbhof'): 1.0925513073499997,
#  ('Zürich, Farbhof', 'Zürich, Micafil'): 0.20336456433150682,
#  ('Zürich, Micafil', 'Zürich, Hermetschloo'): 0.21912926443124997,
#  ('Zürich, Hermetschloo', 'Zürich, Micafil'): 0.8667816750817569,
#  ('Zürich, Micafil', 'Zürich, Farbhof'): 0.8363539910675679,
#  ('Zürich, Farbhof', 'Zürich, Seidelhof'): 1.670160016596385,
#  ('Zürich, Seidelhof', 'Zürich, Bahnhof Altstetten'): 1.6792317678915663,
#  ('Zürich, Bahnhofplatz/HB', 'Zürich, Central'): 0.272584280538433,
#  ('Zürich, Central', 'Zürich, Neumarkt'): 0.4531406761320895,
#  ('Zürich, Neumarkt', 'Zürich, Kunsthaus'): 0.5022796371697762,
#  ('Zürich, Kunsthaus', 'Zürich, Sprecherstrasse'): 1.9941615895757456,
#  ('Zürich, Sprecherstrasse', 'Zürich, Kreuzplatz'): 1.9456045252474075,
#  ('Zürich, Kreuzplatz', 'Zürich, Signaustrasse'): 1.2814627943485175,
#  ('Zürich, Signaustrasse', 'Zürich, Hegibachplatz'): 1.2841250750485185,
#  ('Zürich, Klusplatz', 'Zürich, Kapfstrasse'): 1.233580601761062,
#  ('Zürich, Kapfstrasse', 'Zürich, Schlyfi'): 2.6885279615265496,
#  ('Zürich, Schlyfi', 'Zürich, Drusbergstrasse'): 2.1141920893668154,
#  ('Zürich, Drusbergstrasse', 'Zürich, Waserstrasse'): 0.9879165496706142,
#  ('Zürich, Waserstrasse', 'Zürich, Zentrum Witikon'): 0.6631141576262628,
#  ('Zürich, Zentrum Witikon', 'Zürich, Berghaldenstrasse'): 0.9870866954393939,
#  ('Zürich, Berghaldenstrasse', 'Zürich, Loorenstrasse'): 0.9384624579692983,
#  ('Zürich, Loorenstrasse', 'Zürich, Zweiackerstrasse'): 0.9392644267763154,
#  ('Zürich, Zweiackerstrasse', 'Zürich, Kienastenwies'): 0.8131853441368183,
#  ('Zürich, Kienastenwies', 'Zürich, Zweiackerstrasse'): 1.1560295221553096,
#  ('Zürich, Zweiackerstrasse', 'Zürich, Loorenstrasse'): 1.247331088622566,
#  ('Zürich, Loorenstrasse', 'Zürich, Berghaldenstrasse'): 1.0936116169482297,
#  ('Zürich, Berghaldenstrasse', 'Zürich, Zentrum Witikon'): 1.2870358500680414,
#  ('Zürich, Zentrum Witikon', 'Zürich, Waserstrasse'): 1.7418737072556707,
#  ('Zürich, Waserstrasse', 'Zürich, Drusbergstrasse'): 2.1816365867584073,
#  ('Zürich, Drusbergstrasse', 'Zürich, Schlyfi'): 3.4385696259176983,
#  ('Zürich, Schlyfi', 'Zürich, Kapfstrasse'): 4.299153656332301,
#  ('Zürich, Kapfstrasse', 'Zürich, Klusplatz'): 1.7187673678362836,
#  ('Zürich, Letzipark West', 'Zürich, Albisriederplatz'): 1.5342135,
#  ('Zürich, Bucheggplatz', 'Zürich, Morgental'): 0.6420320746666667,
#  ('Zürich, Botanischer Garten', 'Zürich, Triemli'): 0.9069942843,
#  ('Zürich, Hardplatz', 'Zürich, Bahnhof Wipkingen'): 0.338783225,
#  ('Zürich, In der Ey', 'Zürich, Bahnhof Tiefenbrunnen'): 0.10562982416666666,
#  ('Zürich, Meierhofplatz', 'Zürich, Zwielplatz'): 0.3873996097988638,
#  ('Zürich, Zwielplatz', 'Zürich, Wartau'): 0.42891038888243255,
#  ('Zürich, Wartau', 'Zürich, Zwielplatz'): 0.21794751184729727,
#  ('Zürich, Zwielplatz', 'Zürich, Meierhofplatz'): 0.2029764268608108,
#  ('Zürich, Lettenstrasse', 'Zürich, Giblenstrasse'): 8.629519,
#  ('Zürich, Albisriederplatz', 'Zürich, Triemli'): 0.3304535,
#  ('Zürich, Hardplatz', 'Zürich, Rosengartenstrasse'): 5.298764668333334,
#  ('Zürich, Besenrainstrasse', 'Zürich, Milchbuck'): 1.6335463699999997,
#  ('Zürich, Altes Krematorium', 'Zürich, Rütihof'): 4.4197615,
#  ('Zürich, Botanischer Garten', 'Zürich, Bahnhof Tiefenbrunnen'): 0.203566835,
#  ('Zürich, Friesenbergstrasse', 'Zürich, Zwinglihaus'): 5.256861,
#  ('Zürich, Bahnhof Altstetten', 'Zürich, Kienastenwies'): 0.0021304315,
#  ('Zürich, Bristenstrasse', 'Zürich, Escher-Wyss-Platz'): 4.9075215,
#  ('Zürich, Bahnhof Altstetten', 'Zürich, Letzipark West'): 0.066104605,
#  ('Zürich, Hubertus', 'Zürich, Triemli'): 0.0008192385,
#  ('Zürich, Hardplatz', 'Zürich, Bucheggplatz'): 5.3436395,
#  ('Zürich, Schwandenholz', 'Zürich, Sihlcity'): 3.5321935745625,
#  ('Zürich, Letzibach', 'Zürich, Letzipark West'): 0.0,
#  ('Zürich, Besenrainstrasse', 'Zürich, Rosengartenstrasse'): 3.6305385,
#  ('Zürich, Hungerbergstrasse', 'Zürich, Bucheggplatz'): -0.0007843000000000008,
#  ('Zürich, Hungerbergstrasse', 'Zürich, Strassenverkehrsamt'): 0.0,
#  ('Zürich, Hardplatz', 'Zürich, Bahnhof Tiefenbrunnen'): -0.00837434,
#  ('Zürich, Berghaldenstrasse',
#   'Zürich, Carl-Spitteler-Strasse'): 0.32671320946875004,
#  ('Zürich, Carl-Spitteler-Strasse', 'Zürich, Waserstrasse'): 1.6416958099375,
#  ('Zürich, Waserstrasse',
#   'Zürich, Carl-Spitteler-Strasse'): 0.7727653529333334,
#  ('Zürich, Carl-Spitteler-Strasse',
#   'Zürich, Berghaldenstrasse'): 0.7967162886000002,
#  ('Zürich, Salzweg', 'Zürich, Hardplatz'): 7.1070782999999995,
#  ('Zürich, Altes Krematorium', 'Zürich, Milchbuck'): 0.0979388736,
#  ('Zürich, Wildbachstrasse', 'Zürich, Kirche Fluntern'): 1.2403471939166666,
#  ('Zürich, Sihlquai/HB', 'Zürich, Dunkelhölzli'): 2.1076760030000004,
#  ('Zürich, Zweiackerstrasse', 'Zürich, Bahnhof Altstetten'): 0.1206095615,
#  ('Zürich, Wildbachstrasse', 'Zürich, Rosengartenstrasse'): 0.083808265,
#  ('Zürich, Albisriederplatz', 'Zürich, Schmiede Wiedikon'): 7.2685379999999995,
#  ('Zürich, Zweiackerstrasse', 'Zürich, Drusbergstrasse'): 0.0,
#  ('Zürich, Geeringstrasse', 'Zürich, Segantinistrasse'): 4.6438215,
#  ('Zürich, Geeringstrasse', 'Zürich, Bahnhofquai/HB'): 0.0175833,
#  ('Zürich, Hungerbergstrasse', 'Zürich, Herdernstrasse'): 0.03397026,
#  ('Zürich, Hofstrasse', 'Zürich, Bahnhof Tiefenbrunnen'): 0.43800919725,
#  ('Zürich, Rosengartenstrasse', 'Zürich, Limmatplatz'): 0.0,
#  ('Zürich, Klosbach', 'Zürich, Kirche Fluntern'): 0.390049355,
#  ('Zürich, Triemli', 'Zürich, Hardplatz'): 0.94567825,
#  ('Zürich, Schwert', 'Zürich, Bahnhofquai/HB'): 0.0119086995,
#  ('Zürich, Escher-Wyss-Platz', 'Zürich, Albisriederplatz'): 11.354435500000001,
#  ('Zürich, Bahnhof Hardbrücke', 'Zürich, Bucheggplatz'): 1.833549,
#  ('Zürich, Rosengartenstrasse', 'Zürich, Geeringstrasse'): 4.61782624,
#  ('Zürich, Bahnhof Altstetten', 'Zürich, Hubertus'): 0.1899008565,
#  ('Zürich, Rotbuchstrasse', 'Zürich, Schiffbau'): 5.877859105,
#  ('Zürich, Waffenplatzstrasse', 'Zürich, Besenrainstrasse'): 0.0533905,
#  ('Zürich, Salzweg', 'Zürich, Rütihof'): 3.13616619675,
#  ('Zürich, Albisriederplatz', 'Zürich, Milchbuck'): 0.16978325,
#  ('Zürich, Okenstrasse', 'Zürich, Giblenstrasse'): 0.0,
#  ('Zürich, Waffenplatzstrasse', 'Zürich, Jugendherberge'): 7.494845,
#  ('Zürich, Baslerstrasse', 'Zürich, Hardplatz'): 0.177499145,
#  ('Zürich, Strassenverkehrsamt', 'Zürich, Hungerbergstrasse'): 6.3501965,
#  ('Zürich, Saalsporthalle', 'Zürich, Waidhof'): 5.18592,
#  ('Zürich, Saalsporthalle', 'Zürich, Holzerhurd'): 0.8934565,
#  ('Zürich, Bucheggplatz', 'Zürich, Flurstrasse'): 0.01489209,
#  ('Zürich, Hungerbergstrasse', 'Zürich, Sihlcity'): 0.32085985,
#  ('Zürich, Hofstrasse', 'Zürich, Höschgasse'): 2.6168955615000002,
#  ('Zürich, Hofstrasse', 'Zürich, Freiestrasse'): 8.140354}
